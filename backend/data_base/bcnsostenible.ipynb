# %%
import numpy as np
import pandas as pd
import csv
from geopy.geocoders import Nominatim
from tqdm import tqdm
geolocator = Nominatim(user_agent="geoapiExercises")

# %%
# Execute all cells below until noted

# %%
bcnsost = pd.read_csv("./bcnsostenible.csv", sep='\t')
bcnsost
# Out:
#                           Codi  \
# 0     5391defd0a92f43d0a8b457a
# 1     5391defd0a92f43d0a8b4586
# 2     5391defe0a92f43d0a8b4598
# 3     5391defe0a92f43d0a8b45a3
# 4     5391defe0a92f43d0a8b45b2
# ...                        ...
# 1578  6218c929940cd7ac468b4569
# 1579  6218ccd6940cd7ba468b4567
# 1580  6218d264940cd7bd468b4573
# 1581  621ca305940cd77b2b8b4569
# 1582  621cb5b1940cd7c92d8b4569
#
#                                                     URL  \
# 0     http://www.bcnsostenible.cat/web/punt/5391defd...
# 1     http://www.bcnsostenible.cat/web/punt/5391defd...
# 2     http://www.bcnsostenible.cat/web/punt/5391defe...
# 3     http://www.bcnsostenible.cat/web/punt/5391defe...
# 4     http://www.bcnsostenible.cat/web/punt/5391defe...
# ...                                                 ...
# 1578  http://www.bcnsostenible.cat/web/punt/6218c929...
# 1579  http://www.bcnsostenible.cat/web/punt/6218ccd6...
# 1580  http://www.bcnsostenible.cat/web/punt/6218d264...
# 1581  http://www.bcnsostenible.cat/web/punt/621ca305...
# 1582  http://www.bcnsostenible.cat/web/punt/621cb5b1...
#
#                                                 Nom  \
# 0                Alternativa 3 ONG (Fills del Cafè)
# 1     Associació Bioarquitectura Mediterrània (BAM)
# 2                            Associació Estel Tàpia
# 3                      Associació Social Andròmines
# 4              Bodevici, gelats i iogurts ecològics
# ...                                             ...
# 1578                                       Cruixent
# 1579                                 Forn Santanach
# 1580               La cervecita nuestra de cada día
# 1581                                   Cuinem Barri
# 1582                              La Nau Vila Besòs
#
#                                              Descripció  Telèfon  \
# 0     En l'actualitat és l'única elaboradora de caca...      NaN
# 1     BaM [Bioarquitectura Mediterrània] és una asso...      NaN
# 2     L’Associació Estel Tàpia és una entitat sense ...      NaN
# 3     Des de 1993 lluitem contra l’exclusió des de l...      NaN
# 4     La nostra misió és popularitzar els productes ...      NaN
# ...                                                 ...      ...
# 1578  En aquest forn amb obrador propi s'elaboren to...      NaN
# 1579  <br />\r\nEn aquest forn de pa utilitzen farin...      NaN
# 1580  Aquesta cerveseria ven 8 tipus diferents de ce...      NaN
# 1581  Campanya col·laborativa que proposa a veïns i ...      NaN
# 1582  <strong>Què és la Nau Vila Besòs?</strong><br ...      NaN
#
#                                             Web  E-mail  \
# 0                   http://www.alternativa3.com     NaN
# 1                           http://bamconf.org/     NaN
# 2                     http://www.esteltapia.org     NaN
# 3                     http://www.andromines.net     NaN
# 4                       http://www.bodevici.com     NaN
# ...                                         ...     ...
# 1578      https://josep028.wixsite.com/cruixent     NaN
# 1579                                        NaN     NaN
# 1580                                        NaN     NaN
# 1581         https://cuinembarri.wordpress.com/     NaN
# 1582  https://andromines.net/la-nau-vila-besos/     NaN
#
#                                          Xarxa social 1  \
# 0            https://www.facebook.com/alternativa3Scoop
# 1                https://www.facebook.com/BaMBioarqMed/
# 2                   https://www.facebook.com/esteltapia
# 3     https://www.facebook.com/AndrominesInsercioIMe...
# 4     https://www.facebook.com/bodevici.plaers.ecolo...
# ...                                                 ...
# 1578            https://ca-es.facebook.com/cruixentbcn/
# 1579                                                NaN
# 1580                                                NaN
# 1581                                                NaN
# 1582  https://www.facebook.com/AndrominesInsercioIMe...
#
#                                          Xarxa social 2  \
# 0                      https://twitter.com/alternativa3
# 1                                                   NaN
# 2                        https://twitter.com/EstelTapia
# 3     https://www.facebook.com/AndrominesInsercioIMe...
# 4                          https://twitter.com/Bodevici
# ...                                                 ...
# 1578                                                NaN
# 1579                                                NaN
# 1580                                                NaN
# 1581                                                NaN
# 1582             https://twitter.com/andromines?lang=ca
#
#                                          Xarxa social 3  ... Icona 25  \
# 0            https://www.facebook.com/alternativa3Scoop  ...      NaN
# 1                https://www.facebook.com/BaMBioarqMed/  ...      NaN
# 2                   https://www.facebook.com/esteltapia  ...      NaN
# 3     https://www.facebook.com/AndrominesInsercioIMe...  ...      NaN
# 4     https://www.facebook.com/bodevici.plaers.ecolo...  ...      NaN
# ...                                                 ...  ...      ...
# 1578            https://ca-es.facebook.com/cruixentbcn/  ...      NaN
# 1579                                                NaN  ...      NaN
# 1580                                                NaN  ...      NaN
# 1581                                                NaN  ...      NaN
# 1582  https://www.facebook.com/AndrominesInsercioIMe...  ...      NaN
#
#      Icona 26 Icona 27 Icona 28 Icona 29 Icona 30 Icona 31 Icona 32  \
# 0         NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1         NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2         NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 3         NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 4         NaN      NaN      NaN      NaN      NaN      NaN      NaN
# ...       ...      ...      ...      ...      ...      ...      ...
# 1578      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1579      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1580      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1581      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1582      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#                                               Etiquetes  \
# 0                                      EiESos,EmpresaBS
# 1     EiESos,EntitatBS,ConstruccióSostenible,Caminad...
# 2                                      EiESos,EntitatBS
# 3                                      EiESos,EntitatBS
# 4                          comsos,EmpresaBS,Caminades19
# ...                                                 ...
# 1578                                        comerç verd
# 1579                                        comerç verd
# 1580                                        comerç verd
# 1581                                                NaN
# 1582                                                NaN
#
#                                              Itineraris
# 0                                                   NaN
# 1     Caminades per la Sostenibilitat 2019: Més enll...
# 2     L’economia social, solidària i cooperativa al ...
# 3                                                   NaN
# 4     Comerç Verd de la Vila de Gràcia ( https://bcn...
# ...                                                 ...
# 1578  Comerç Verd de Sant Martí ( https://bcnsosteni...
# 1579  Comerç Verd de Sant Martí ( https://bcnsosteni...
# 1580  Comerç Verd de Sant Martí ( https://bcnsosteni...
# 1581                                                NaN
# 1582  Barcelona Recircula ( https://bcnsostenible.ca...
#
# [1583 rows x 50 columns]

# %%
bcnsost.drop(['Icona ' + str(i) for i in range(2, 33)], inplace = True, axis=1)
bcnsost.drop(['Xarxa social ' + str(i) for i in range(1, 5)], inplace = True, axis=1)
bcnsost["location"] = list(zip(list(bcnsost["Latitud"]), list(bcnsost["Longitud"])))
bcnsost.drop(['Codi', 'URL', 'E-mail', 'Itineraris', 'Telèfon', 'Icona 1 (Principal)', 'Latitud', 'Longitud'], inplace = True, axis=1)
bcnsost = bcnsost.rename(columns={
    'Nom': 'shopname', 'Telèfon': 'shop phone', 'Descripció': 'description', 'Web': 'web', 'Adreça': 'address', 
    'Districte': 'district', 'Barri': 'neighbourhood'})

# %%
bcnsost
# Out:
#                                            shopname  \
# 0                Alternativa 3 ONG (Fills del Cafè)
# 1     Associació Bioarquitectura Mediterrània (BAM)
# 2                            Associació Estel Tàpia
# 3                      Associació Social Andròmines
# 4              Bodevici, gelats i iogurts ecològics
# ...                                             ...
# 1578                                       Cruixent
# 1579                                 Forn Santanach
# 1580               La cervecita nuestra de cada día
# 1581                                   Cuinem Barri
# 1582                              La Nau Vila Besòs
#
#                                             description  \
# 0     En l'actualitat és l'única elaboradora de caca...
# 1     BaM [Bioarquitectura Mediterrània] és una asso...
# 2     L’Associació Estel Tàpia és una entitat sense ...
# 3     Des de 1993 lluitem contra l’exclusió des de l...
# 4     La nostra misió és popularitzar els productes ...
# ...                                                 ...
# 1578  En aquest forn amb obrador propi s'elaboren to...
# 1579  <br />\r\nEn aquest forn de pa utilitzen farin...
# 1580  Aquesta cerveseria ven 8 tipus diferents de ce...
# 1581  Campanya col·laborativa que proposa a veïns i ...
# 1582  <strong>Què és la Nau Vila Besòs?</strong><br ...
#
#                                             web  \
# 0                   http://www.alternativa3.com
# 1                           http://bamconf.org/
# 2                     http://www.esteltapia.org
# 3                     http://www.andromines.net
# 4                       http://www.bodevici.com
# ...                                         ...
# 1578      https://josep028.wixsite.com/cruixent
# 1579                                        NaN
# 1580                                        NaN
# 1581         https://cuinembarri.wordpress.com/
# 1582  https://andromines.net/la-nau-vila-besos/
#
#                                   address      district  \
# 0                                     NaN           NaN
# 1                        Carrer Àlaba, 24    Sant Martí
# 2                     carrer de l'Om, 7-9  Ciutat Vella
# 3                         Carrer Cuba, 24   Sant Andreu
# 4                     Carrer Torrijos, 21        Gràcia
# ...                                   ...           ...
# 1578                      C/ Pujades, 173    Sant Martí
# 1579              Rambla del Poblenou, 98    Sant Martí
# 1580                 Carrer de Llull, 184    Sant Martí
# 1581                   Rambla de Prim, 87    Sant Martí
# 1582  Passatge Torrent de l'Estadella, 11   Sant Andreu
#
#                           neighbourhood  \
# 0                                   NaN
# 1     El Parc i la Llacuna del Poblenou
# 2                              El Raval
# 3                           Sant Andreu
# 4                        Vila de Gràcia
# ...                                 ...
# 1578                        El Poblenou
# 1579                        El Poblenou
# 1580                        El Poblenou
# 1581              El Besòs i el Maresme
# 1582                         Bon Pastor
#
#                                               Etiquetes  \
# 0                                      EiESos,EmpresaBS
# 1     EiESos,EntitatBS,ConstruccióSostenible,Caminad...
# 2                                      EiESos,EntitatBS
# 3                                      EiESos,EntitatBS
# 4                          comsos,EmpresaBS,Caminades19
# ...                                                 ...
# 1578                                        comerç verd
# 1579                                        comerç verd
# 1580                                        comerç verd
# 1581                                                NaN
# 1582                                                NaN
#
#                        location
# 0      (0,00000000, 0,00000000)
# 1     (41,40305800, 2,18850910)
# 2     (41,37607410, 2,17195180)
# 3     (41,42930740, 2,18874940)
# 4     (41,40328780, 2,15889560)
# ...                         ...
# 1578  (41,40188090, 2,20072905)
# 1579  (41,40219475, 2,19993512)
# 1580  (41,40035650, 2,20158850)
# 1581  (41,41648840, 2,21181180)
# 1582  (41,43305350, 2,20035150)
#
# [1583 rows x 8 columns]

# %%
bcnsost = bcnsost.loc[['comerç verd' in str(tags) for tags in list(bcnsost['Etiquetes'])]]
bcnsost.drop('Etiquetes', inplace=True, axis=1)
bcnsost
# Out:
# <ipython-input-6-fbfa53960789>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bcnsost.drop('Etiquetes', inplace=True, axis=1)
#                               shopname  \
# 153                          Vida Meva
# 323                Bodega El Mallorquí
# 385                      The Tea World
# 418                  La Botiga Natural
# 656                         Espai Bici
# ...                                ...
# 1576            YES FUTURE El Poblenou
# 1577            Teixidor taula i cuina
# 1578                          Cruixent
# 1579                    Forn Santanach
# 1580  La cervecita nuestra de cada día
#
#                                             description  \
# 153   Aquest comerç porta ja més de 10 anys al barri...
# 323   Establiment on es poden trobar vi, licors i al...
# 385   The Tea World neix el setembre de 2011, com a ...
# 418   Alimentació i herbodietètica ECO. Fruita, verd...
# 656   Espai dedicat a la bicicleta com a mitjà de tr...
# ...                                                 ...
# 1576  Nou model de supermercat que només ofereix pro...
# 1577  <br />\r\nEn aquest comerç podem trobar difere...
# 1578  En aquest forn amb obrador propi s'elaboren to...
# 1579  <br />\r\nEn aquest forn de pa utilitzen farin...
# 1580  Aquesta cerveseria ven 8 tipus diferents de ce...
#
#                                          web                  address  \
# 153                    https://vidameva.com/  Carrer Ramon Turró, 201
# 323                                      NaN      Carrer de Verdi, 61
# 385              https://www.theteaworld.es/       Carrer Marina, 271
# 418   https://labotiganatural.com/index.php?     Carrer Rosselló, 441
# 656                 http://www.espaibici.com          Carrer Bruc, 63
# ...                                      ...                      ...
# 1576             http://www.yesfuture.store/   Carrer de Pujades, 197
# 1577           https://www.angelteixido.com/      Carrer Pallars, 224
# 1578   https://josep028.wixsite.com/cruixent          C/ Pujades, 173
# 1579                                     NaN  Rambla del Poblenou, 98
# 1580                                     NaN     Carrer de Llull, 184
#
#         district        neighbourhood                   location
# 153   Sant Martí          El Poblenou  (41,40045850, 2,20339790)
# 323       Gràcia       Vila de Gràcia  (41,40461780, 2,15601690)
# 385     Eixample      Sagrada Família  (41,40508280, 2,17348830)
# 418     Eixample      Sagrada Família  (41,40575950, 2,17366950)
# 656     Eixample  Dreta de l'Eixample  (41,39368290, 2,17021380)
# ...          ...                  ...                        ...
# 1576  Sant Martí          El Poblenou  (41,40295122, 2,20223109)
# 1577  Sant Martí          El Poblenou  (41,40262570, 2,19991290)
# 1578  Sant Martí          El Poblenou  (41,40188090, 2,20072905)
# 1579  Sant Martí          El Poblenou  (41,40219475, 2,19993512)
# 1580  Sant Martí          El Poblenou  (41,40035650, 2,20158850)
#
# [304 rows x 7 columns]

# %%
bcnsost.iloc[60:90]['description']
# Out:
# 737    Botiga d’alimentació ecològica. Fruita i verdu...
# 738    Papereria i llibreria. Tenen oferta de paper r...
# 739    Supermercat de productes ecològics i biològics...
# 740    Botiga amb venda d'estris i elements per a fer...
# 741    Tenen llibretes de paper reciclat, tòner eco i...
# 742    Botiga d'herbodietètica i osteopatia. Tenen al...
# 743    Tenen producte a granel, tant d'alimentació co...
# 750    Botiga de venda de fruita i verdura amb selecc...
# 751    Botiga de criança sostenible. Productes de pue...
# 752    Botiga especialitzada en venda de bolquers de ...
# 753    Botiga de venda de vins orgànics. Tenen selecc...
# 754    Botiga de venda de mobles de fusta recuperada....
# 755    Botiga de venda de pastisseria vegana. Tots el...
# 756    Botiga de venda de productes frescos ecològics...
# 757    Botiga de venda de producte a granel de proxim...
# 758    Botiga de venda de producte a granel de proxim...
# 759    Botiga de venda de pa i pastisseria fets amb f...
# 760    Fruiteria i verduleria ecològica. Selecció de ...
# 761    Botiga de venda de productes d’alimentació eco...
# 762    Botiga de venda de carn ecològica. Tenen vedel...
# 763    Botiga de venda de teles. Tenen cotons orgànic...
# 783    Centre de teràpies i productes naturals; tenen...
# 785    Roba de cotó orgànic produïda a Mataró i de di...
# 786    Pastisseria amb productes vegans (pastissos, p...
# 787    Tenen compreses de cotó orgànic, copa menstrua...
# 788    Forn de pa 100 % ecològic. Fan massa mare i te...
# 789    Productes de neteja per a la llar, detergents,...
# 790    Botiga amb venda de vins ecològics, biodinàmic...
# 791    Botiga amb venda a granel de llegums, fruits s...
# 792              Mobles i objectes diversos de segona mà
# Name: description, dtype: object

# %%
from random import choices, sample
types = ['restaurant', 'bar', 'supermarket', 'alimentation', 'beverages', 'bakery',
         'fruits & vegetables', 'pharmacy', 'cosmetics', 'herbalist', 'non-alimentation', 'others']
types_sample = choices(types, k=len(bcnsost))
bcnsost['type'] = types_sample

tags = ['restaurant', 'bar', 'supermarket', 'bakery', 'vegan food', 'vegetarian food',
         'beverages', 'alimentation', 'local products', 'green space', 'plastic free',
         'zero waste', 'herbalist', 'second hand', 'in bulk', 'cosmetics', 'pharmacy',
         'fruits & vegetables', 'recycled material', 'others']
tags_sample = [sample(tags, k=3) for i in range(len(bcnsost))]
bcnsost['tags'] = tags_sample

bcnsost['timetable'] = [None]*len(bcnsost)
bcnsost['photo'] = [None]*len(bcnsost)
bcnsost['product_list'] = [None]*len(bcnsost)
bcnsost['phone'] = [None]*len(bcnsost)

bcnsost
# Out:
# <ipython-input-8-19e22807bcec>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bcnsost['type'] = types_sample
# <ipython-input-8-19e22807bcec>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bcnsost['tags'] = tags_sample
# <ipython-input-8-19e22807bcec>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bcnsost['timetable'] = [None]*len(bcnsost)
# <ipython-input-8-19e22807bcec>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bcnsost['photo'] = [None]*len(bcnsost)
# <ipython-input-8-19e22807bcec>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bcnsost['product_list'] = [None]*len(bcnsost)
# <ipython-input-8-19e22807bcec>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bcnsost['phone'] = [None]*len(bcnsost)
#                               shopname  \
# 153                          Vida Meva
# 323                Bodega El Mallorquí
# 385                      The Tea World
# 418                  La Botiga Natural
# 656                         Espai Bici
# ...                                ...
# 1576            YES FUTURE El Poblenou
# 1577            Teixidor taula i cuina
# 1578                          Cruixent
# 1579                    Forn Santanach
# 1580  La cervecita nuestra de cada día
#
#                                             description  \
# 153   Aquest comerç porta ja més de 10 anys al barri...
# 323   Establiment on es poden trobar vi, licors i al...
# 385   The Tea World neix el setembre de 2011, com a ...
# 418   Alimentació i herbodietètica ECO. Fruita, verd...
# 656   Espai dedicat a la bicicleta com a mitjà de tr...
# ...                                                 ...
# 1576  Nou model de supermercat que només ofereix pro...
# 1577  <br />\r\nEn aquest comerç podem trobar difere...
# 1578  En aquest forn amb obrador propi s'elaboren to...
# 1579  <br />\r\nEn aquest forn de pa utilitzen farin...
# 1580  Aquesta cerveseria ven 8 tipus diferents de ce...
#
#                                          web                  address  \
# 153                    https://vidameva.com/  Carrer Ramon Turró, 201
# 323                                      NaN      Carrer de Verdi, 61
# 385              https://www.theteaworld.es/       Carrer Marina, 271
# 418   https://labotiganatural.com/index.php?     Carrer Rosselló, 441
# 656                 http://www.espaibici.com          Carrer Bruc, 63
# ...                                      ...                      ...
# 1576             http://www.yesfuture.store/   Carrer de Pujades, 197
# 1577           https://www.angelteixido.com/      Carrer Pallars, 224
# 1578   https://josep028.wixsite.com/cruixent          C/ Pujades, 173
# 1579                                     NaN  Rambla del Poblenou, 98
# 1580                                     NaN     Carrer de Llull, 184
#
#         district        neighbourhood                   location  \
# 153   Sant Martí          El Poblenou  (41,40045850, 2,20339790)
# 323       Gràcia       Vila de Gràcia  (41,40461780, 2,15601690)
# 385     Eixample      Sagrada Família  (41,40508280, 2,17348830)
# 418     Eixample      Sagrada Família  (41,40575950, 2,17366950)
# 656     Eixample  Dreta de l'Eixample  (41,39368290, 2,17021380)
# ...          ...                  ...                        ...
# 1576  Sant Martí          El Poblenou  (41,40295122, 2,20223109)
# 1577  Sant Martí          El Poblenou  (41,40262570, 2,19991290)
# 1578  Sant Martí          El Poblenou  (41,40188090, 2,20072905)
# 1579  Sant Martí          El Poblenou  (41,40219475, 2,19993512)
# 1580  Sant Martí          El Poblenou  (41,40035650, 2,20158850)
#
#                   type                                               tags  \
# 153             bakery                 [vegan food, herbalist, cosmetics]
# 323   non-alimentation           [vegetarian food, restaurant, herbalist]
# 385         restaurant               [beverages, vegan food, green space]
# 418             others            [vegan food, plastic free, green space]
# 656       alimentation            [fruits & vegetables, bar, green space]
# ...                ...                                                ...
# 1576               bar  [green space, fruits & vegetables, vegetarian ...
# 1577               bar             [others, supermarket, vegetarian food]
# 1578  non-alimentation               [restaurant, beverages, supermarket]
# 1579            bakery                    [others, pharmacy, green space]
# 1580        restaurant                       [others, zero waste, bakery]
#
#      timetable photo product_list phone
# 153       None  None         None  None
# 323       None  None         None  None
# 385       None  None         None  None
# 418       None  None         None  None
# 656       None  None         None  None
# ...        ...   ...          ...   ...
# 1576      None  None         None  None
# 1577      None  None         None  None
# 1578      None  None         None  None
# 1579      None  None         None  None
# 1580      None  None         None  None
#
# [304 rows x 13 columns]

# %%
bcnsost = bcnsost[bcnsost['address'].notna()]
full_address = zip(bcnsost['address'], bcnsost['district'], bcnsost['neighbourhood'])
full_address = [', '.join(add) for add in full_address]
full_address = [geolocator.geocode(add) for add in tqdm(full_address)]
bcnsost = bcnsost[[add is not None for add in full_address]]
full_address = [add for add in full_address if add is not None]
zip_codes = [add[0].split(', ')[-2] for add in full_address]
# Out:
# 100%|██████████| 302/302 [02:30<00:00,  2.00it/s]

# %%
bcnsost['zip_code'] = zip_codes
colnames = bcnsost.columns.tolist()
colnames = colnames[:7] + [colnames[-1]] + colnames[7:-1]
colnames
bcnsost = bcnsost[colnames]
bcnsost
# Out:
#                               shopname  \
# 153                          Vida Meva
# 323                Bodega El Mallorquí
# 385                      The Tea World
# 418                  La Botiga Natural
# 656                         Espai Bici
# ...                                ...
# 1576            YES FUTURE El Poblenou
# 1577            Teixidor taula i cuina
# 1578                          Cruixent
# 1579                    Forn Santanach
# 1580  La cervecita nuestra de cada día
#
#                                             description  \
# 153   Aquest comerç porta ja més de 10 anys al barri...
# 323   Establiment on es poden trobar vi, licors i al...
# 385   The Tea World neix el setembre de 2011, com a ...
# 418   Alimentació i herbodietètica ECO. Fruita, verd...
# 656   Espai dedicat a la bicicleta com a mitjà de tr...
# ...                                                 ...
# 1576  Nou model de supermercat que només ofereix pro...
# 1577  <br />\r\nEn aquest comerç podem trobar difere...
# 1578  En aquest forn amb obrador propi s'elaboren to...
# 1579  <br />\r\nEn aquest forn de pa utilitzen farin...
# 1580  Aquesta cerveseria ven 8 tipus diferents de ce...
#
#                                          web                  address  \
# 153                    https://vidameva.com/  Carrer Ramon Turró, 201
# 323                                      NaN      Carrer de Verdi, 61
# 385              https://www.theteaworld.es/       Carrer Marina, 271
# 418   https://labotiganatural.com/index.php?     Carrer Rosselló, 441
# 656                 http://www.espaibici.com          Carrer Bruc, 63
# ...                                      ...                      ...
# 1576             http://www.yesfuture.store/   Carrer de Pujades, 197
# 1577           https://www.angelteixido.com/      Carrer Pallars, 224
# 1578   https://josep028.wixsite.com/cruixent          C/ Pujades, 173
# 1579                                     NaN  Rambla del Poblenou, 98
# 1580                                     NaN     Carrer de Llull, 184
#
#         district        neighbourhood                   location zip_code  \
# 153   Sant Martí          El Poblenou  (41,40045850, 2,20339790)    08001
# 323       Gràcia       Vila de Gràcia  (41,40461780, 2,15601690)    08012
# 385     Eixample      Sagrada Família  (41,40508280, 2,17348830)    08001
# 418     Eixample      Sagrada Família  (41,40575950, 2,17366950)    08001
# 656     Eixample  Dreta de l'Eixample  (41,39368290, 2,17021380)    08009
# ...          ...                  ...                        ...      ...
# 1576  Sant Martí          El Poblenou  (41,40295122, 2,20223109)    08005
# 1577  Sant Martí          El Poblenou  (41,40262570, 2,19991290)    08005
# 1578  Sant Martí          El Poblenou  (41,40188090, 2,20072905)    08001
# 1579  Sant Martí          El Poblenou  (41,40219475, 2,19993512)    08005
# 1580  Sant Martí          El Poblenou  (41,40035650, 2,20158850)    08001
#
#                   type                                               tags  \
# 153             bakery                 [vegan food, herbalist, cosmetics]
# 323   non-alimentation           [vegetarian food, restaurant, herbalist]
# 385         restaurant               [beverages, vegan food, green space]
# 418             others            [vegan food, plastic free, green space]
# 656       alimentation            [fruits & vegetables, bar, green space]
# ...                ...                                                ...
# 1576               bar  [green space, fruits & vegetables, vegetarian ...
# 1577               bar             [others, supermarket, vegetarian food]
# 1578  non-alimentation               [restaurant, beverages, supermarket]
# 1579            bakery                    [others, pharmacy, green space]
# 1580        restaurant                       [others, zero waste, bakery]
#
#      timetable photo product_list phone
# 153       None  None         None  None
# 323       None  None         None  None
# 385       None  None         None  None
# 418       None  None         None  None
# 656       None  None         None  None
# ...        ...   ...          ...   ...
# 1576      None  None         None  None
# 1577      None  None         None  None
# 1578      None  None         None  None
# 1579      None  None         None  None
# 1580      None  None         None  None
#
# [278 rows x 14 columns]

# %%
# Make all extra modifications here, before saving

# %%
bcnsost.to_csv('shops.csv')

# %%
# Ignore this it was for testing

# %%
tags = [t.split(',') for t in bcnsost['Etiquetes'] if type(t) == str]
tags = list(dict.fromkeys(sum(tags, [])))

# %%
tags
# Out:
# ['EiESos',
#  'EmpresaBS',
#  'EntitatBS',
#  'ConstruccióSostenible',
#  'Caminades19',
#  'comsos',
#  'Signants_EA',
#  'CBClima',
#  'RenovaRoba17',
#  'RenovaJocs17',
#  'RenovaRoba19',
#  'RenovaJoguines19',
#  'AiguArt20',
#  'RenovaRoba20Maig',
#  'HortsComunitaris',
#  'Oficiibenefici',
#  'Sssplau1718',
#  'EHMT1819',
#  'actualització2122',
#  'triennal21-24',
#  'EMS_ES2122',
#  'embolcallsES',
#  'continuïtat21-22',
#  '',
#  'EmbolcallsES17-18',
#  'EmbolcallsES1819',
#  'EmbolcallsES1920',
#  'millora21-22',
#  'FemCampanyaMobilitat',
#  'Sssplau1516',
#  'Sssplau1617',
#  'MapaSoroll1617',
#  'triennal19-22',
#  'ppr_es2122',
#  'DiaMundialConscienciacióEnversSoroll17',
#  'PPR_ES',
#  'TCP1718',
#  'TCP1819',
#  'PPR_ES1819',
#  'PPR_ES1920',
#  'emt_es2122',
#  'se_es2122',
#  'triennal20-23',
#  'com_es2122',
#  'aas_es2122',
#  'EHMT',
#  'EHMT1617',
#  'Sssplau1819',
#  'ERespira_ES1920',
#  'sss_es2122',
#  'dn_es2122',
#  'Sssplau1920',
#  'er_es2122',
#  'air_es2122',
#  'Sssplau1415',
#  'inici21-22',
#  'TexansPelClima',
#  'AaS_ES2122',
#  'plàsticzero',
#  'comerç verd',
#  'ReparacióTèxtil',
#  'SetPrevRes2020',
#  'HortSocial',
#  'EquipamentBS',
#  'RenovaJove17',
#  'RenovaJove19',
#  'RenovaRobaTardor21',
#  'TresTurons',
#  '#TurismESS',
#  'Detergents granel',
#  'cicleaigua',
#  'RecComtal',
#  'BotigaRobaAmiga',
#  'BotigaHumana',
#  'moda',
#  'sostenible',
#  'texans',
#  'ètica',
#  'cosmétics',
#  'naturals',
#  'artesania',
#  'disseny gràfic',
#  'laboratori creatiu',
#  'vegana',
#  'sabateria',
#  'slow',
#  'local',
#  'reciclatge',
#  'comerç just',
#  'disseny',
#  'Barcelona',
#  'art',
#  'galeria',
#  'EmpresaBSpl',
#  'UniversitatBS',
#  'AdministracioBS',
#  'TerraTecaTraca',
#  'restaurant',
#  'alimentaciósostenible',
#  'Empresa']

# %%
with open('shops.csv') as f:
    shops = [{k: v for k, v in list(row.items())[1:]}
        for row in csv.DictReader(f, skipinitialspace=True)]
shops
# Out:
# [{'shopname': 'Vida Meva',
#   'description': "Aquest comerç porta ja més de 10 anys al barri fomentant el consum responsable. Seguint la filosofia de la botiga, treballen amb fruita i verdura directament de pagesos d'horta ecològica, de temporada i de proximitat escurçant els circuits de comercialització en la mesura del possible. Tenen un ampli ventall de productes a granel i alguns productes ecològics empaquetats. A més, també s'hi poden trobar ampolles d’aigua retornables de vidre.<br />\nIncentiven la utilització de materials reutilitzables però també ofereixen bosses de paper reciclat. L'oferta és aproximadament un 90% de productes ecològics i la resta són petits artesans de proximitat. Tenen una secció que es diu “El racó dels convidats” segons temporada aposten per petits productors amb propostes sostenibles, per exemple en aquesta secció hi podem trobar la marca “imperfect”.<br />\nOrganitzen sortides per conèixer els productors que els proveeixen els productes.<br />\n\xa0",
#   'web': 'https://vidameva.com/',
#   'adress': 'Carrer Ramon Turró, 201',
#   'district': 'Sant Martí',
#   'neighbourhood': 'El Poblenou',
#   'location': "('41,40045850', '2,20339790')",
#   'type': 'supermarket'},
#  {'shopname': 'Bodega El Mallorquí',
#   'description': 'Establiment on es poden trobar vi, licors i altres begudes a granel i embotellades, algunes ecològiques. Cervesa artesana',
#   'web': '',
#   'adress': 'Carrer de Verdi, 61',
#   'district': 'Gràcia',
#   'neighbourhood': 'Vila de Gràcia',
#   'location': "('41,40461780', '2,15601690')",
#   'type': 'supermarket'},
#  {'shopname': 'The Tea World',
#   'description': "The Tea World neix el setembre de 2011, com a negoci familiar enfocat al món del te i el cafè.<br />\nMitjançant la nostra botiga i experiència, volem crear un punt de referència per a amants de te a granel de la millor qualitat i cafè de la seva millor producció.<br />\n\xa0<br />\nDisposem de més de 145 referències de Te, Infusions i Rooibos a granel, procedents directament de les millors zones de producció a nivell mundial. Els nostres Cafès procedeixen de les més importants zones de producció, Amèrica del Sud i Àfrica.<br />\n\xa0<br />\nA The Tea World treballem per aconseguir la millor qualitat i varietat dels nostres productes.<br />\n\xa0<br />\nA més, disposem d'una àmplia gamma d'accessoris i complements per a l'ús i gaudi del Te i el Cafè.<br />\n\xa0<br />\n<br />\nEt donem la benvinguda a la nostra botiga virtual!",
#   'web': 'https://www.theteaworld.es/',
#   'adress': 'Carrer Marina, 271',
#   'district': 'Eixample',
#   'neighbourhood': 'Sagrada Família',
#   'location': "('41,40508280', '2,17348830')",
#   'type': 'others'},
#  {'shopname': 'La Botiga Natural',
#   'description': 'Alimentació i herbodietètica ECO. Fruita, verdura i nous a granel. El producte és de proximitat en la mesura del possible, tenen algun producte de comerç just i ofereixen bosses compostables.',
#   'web': 'https://labotiganatural.com/index.php?',
#   'adress': 'Carrer Rosselló, 441',
#   'district': 'Eixample',
#   'neighbourhood': 'Sagrada Família',
#   'location': "('41,40575950', '2,17366950')",
#   'type': 'others'},
#  {'shopname': 'Espai Bici',
#   'description': 'Espai dedicat a la bicicleta com a mitjà de transport. Venda i taller de reparació de bicicletes.',
#   'web': 'http://www.espaibici.com',
#   'adress': 'Carrer Bruc, 63',
#   'district': 'Eixample',
#   'neighbourhood': "Dreta de l'Eixample",
#   'location': "('41,39368290', '2,17021380')",
#   'type': 'beverages'},
#  {'shopname': 'PanAmà - La tradició del pa',
#   'description': 'Forn de pa artesà fet a mà, elaborat amb massa mare i fermentació lenta de 12 hores.<br />\nUtilitzen 4 tipus de farina ecològica i de proximitat (sègol, civada, integral i de pedra).<br />\nFan entrega en bicicleta a residències i restaurants.',
#   'web': '',
#   'adress': 'Casp, 39',
#   'district': 'Eixample',
#   'neighbourhood': "Dreta de l'Eixample",
#   'location': "('41,39174820', '2,17370311')",
#   'type': 'alimentation'},
#  {'shopname': 'Gram Biològic',
#   'description': "Botiga d'alimentació, cosmètica i complements ecològics.<br />\nVins, fruites i verdures de proximitat i ecològiques.<br />\nAssessorament.",
#   'web': '',
#   'adress': 'Carrer de València, 305',
#   'district': 'Eixample',
#   'neighbourhood': "Dreta de l'Eixample",
#   'location': "('41,39620710', '2,16770569')",
#   'type': 'green space'},
#  {'shopname': 'Crearte Styling',
#   'description': 'Perruqueria i estètica amb productes ecològics certificats, tints lliures de plom i altres tòxics. Maquillatge natural, esmalt ecològic...<br />\n<br />\nL’ús de productes amb compostos estrictament naturals, tècniques de treball de consum mínim i una cura detallada dels residus, va valdre a Crearte el premi “Barcelona la millor Botiga del Món” a la millor iniciativa empresarial que atorga l’Ajuntament de Barcelona. Tots els productes són alemanys «Bioestetique».',
#   'web': 'http://www.creartestyling.com/',
#   'adress': 'Carrer de Girona, 134',
#   'district': 'Eixample',
#   'neighbourhood': "Dreta de l'Eixample",
#   'location': "('41,39800190', '2,16710190')",
#   'type': 'alimentation'},
#  {'shopname': 'Columpiu',
#   'description': 'Botiga de mobles de segona mà amb encant.',
#   'web': 'https://columpiu.wordpress.com/',
#   'adress': 'Carrer de Bailèn, 147',
#   'district': 'Eixample',
#   'neighbourhood': "Dreta de l'Eixample",
#   'location': "('41,39965168', '2,16658989')",
#   'type': 'restaurant'},
#  {'shopname': 'Cosmètica Natural Elna',
#   'description': 'Botiga de cosmètica natural.',
#   'web': 'https://cosmeticaelna.wordpress.com',
#   'adress': 'St. Pere Més Baix, 14',
#   'district': 'Ciutat Vella',
#   'neighbourhood': 'Sant Pere, Santa Caterina i la Ribera',
#   'location': "('41,38663698', '2,17675010')",
#   'type': 'restaurant'},
#  {'shopname': 'La Hamaca',
#   'description': "Sucs, batuts, smoothies fets al moment amb fruita i verdures naturals.<br />\nFruita i verdura ecològica i/o km 0.<br />\nAltres productes d'alimentació ecològics: cafè, mel. etc.<br />\n\xa0",
#   'web': 'http://lahamacabcn.com',
#   'adress': 'Pl. Sant Agustí Vell, 15',
#   'district': 'Ciutat Vella',
#   'neighbourhood': 'Sant Pere, Santa Caterina i la Ribera',
#   'location': "('41,38778402', '2,18072514')",
#   'type': 'local food'},
#  {'shopname': 'Baobab Company',
#   'description': 'Baobab Company és una marca de "Prêt-à-porter" i de samarretes nascuda a l\'Oceà Índic el 1995 amb la promoció dels valors humans, de comerç just i de roba ecològica (GOTS).<br />\n\xa0',
#   'web': 'https://www.baobabcompany.net',
#   'adress': 'Allada Vermell, 14',
#   'district': 'Ciutat Vella',
#   'neighbourhood': 'Sant Pere, Santa Caterina i la Ribera',
#   'location': "('41,38685432', '2,18095581')",
#   'type': 'beverages'},
#  {'shopname': 'Casa Gispert',
#   'description': 'Establiment on es venen a granel fruits secs, tés, cafès, herbes, espècies i oli.<br />\n<br />\nEn 1851, en ple centre de Barcelona, neix Casa Gispert.<br />\n<br />\nCasa Gispert és una de les empreses d’alimentació més antigues de Barcelona. La botiga es troba al centre de la ciutat comtal, al costat de la basílica de Santa Maria del Mar, molt a prop del Museu Picasso. Casa Gispert ven productes colonials des de 1851: fruits secs, fruita dessecada, cafè, te, cacau, espècies com la vainilla, la canyella, el safrà … i l’interior de la botiga ha estat conservat en el seu estat original, com un museu però encara funcionant. Avui en dia, Casa Gispert ofereix també una gran diversitat d’altres productes, ecològics, olis d’oliva verge extres, vinagres, xocolates, torrons, mels, melmelades, vins dolços, cistells de regal, etc. sempre a la recerca de productes locals i de gran qualitat.',
#   'web': 'http://www.casagispert.com',
#   'adress': 'Carrer Sombrerers, 23',
#   'district': 'Ciutat Vella',
#   'neighbourhood': 'Sant Pere, Santa Caterina i la Ribera',
#   'location': "('41,38409330', '2,18188921')",
#   'type': 'green space'},
#  {'shopname': 'Casa Perris',
#   'description': "Graneria de qualitat fundada al 1940. Venda de productes a granel: llegums, llavors, arrossos, fruits secs, entre d'altres. Tenen oferta de productes ecològics i fan servir bosses de plàstic biodegradable, paperines o bosses de roba.",
#   'web': 'http://www.casaperris.com/Torras/index.jsp',
#   'adress': 'Plaça Comercial, 2',
#   'district': 'Ciutat Vella',
#   'neighbourhood': 'Sant Pere, Santa Caterina i la Ribera',
#   'location': "('41,38592863', '2,18281189')",
#   'type': 'beverages'},
#  {'shopname': 'Henna Morena',
#   'description': 'Cosmètica natural i mediterrània i perruqueria ecològica.',
#   'web': 'https://www.hennamorena.com',
#   'adress': 'Esparteria, 12',
#   'district': 'Ciutat Vella',
#   'neighbourhood': 'Sant Pere, Santa Caterina i la Ribera',
#   'location': "('41,38416575', '2,18312303')",
#   'type': 'restaurant'},
#  {'shopname': 'Amantis Gràcia',
#   'description': 'Botiga eròtica amb productes ecològics, vegans, de proximitat i de comerç just.<br />\nEspecialitzada en llibres, eines per a la millora de la sexualitat, llenceria, vibradors, joguines i jocs de taula eròtics, complements per al BDSM, condons, cosmètica eròtica,... A més promouen el reciclatge de joguines i el transport sostenible, fent un 5% de desompte als clients que vagin en bicicleta.\xa0<br />\n<br />\n\xa0',
#   'web': 'http://ccpatchwork.es',
#   'adress': "Torrent de l'Olla, 145",
#   'district': 'Gràcia',
#   'neighbourhood': 'Vila de Gràcia',
#   'location': "('41,40370768', '2,15530316')",
#   'type': 'green space'},
#  {'shopname': 'Olokuti',
#   'description': 'Olokuti promou un consum responsable basat en el comerç just, productes ecològics, biològics, artesanals i culturals.<br />\nLa nostra filosofia és que es pot aconseguir una equitat i un intercanvi més just a través de les nostres compres.<br />\nTambé es realitzen activitats al jardí a la primavera-tardor (cinema, xerrades, exposicions, ...).<br />\n\xa0',
#   'web': 'http://www.olokuti.com',
#   'adress': 'Carrer Astúries, 36',
#   'district': 'Gràcia',
#   'neighbourhood': 'Vila de Gràcia',
#   'location': "('41,40345016', '2,15461651')",
#   'type': 'green space'},
#  {'shopname': 'Surinyach Pasta i Gra',
#   'description': "Alimentació a granel en pasta, arròs, espècies, tes, fruits secs, i més...A Surinyach Pasta i Gra apostem per recuperar el comerç de proximitat què tan caracteritzava la nostra ciutat. Hem treballat per dissenyar un espai on els clients gaudeixin i se sentin còmodes.<br />\n\xa0<br />\nMentre preparàvem el projecte, hem seleccionat acuradament els nostres proveïdors. Per això \xa0oferim els nostres productes amb total confiança als nostres clients.<br />\nFruits secs torrats amb forn de llenya; pasta alimentària fabricada amb mètodes tradicionals seguits per vuit generacions de mestres artesans; espècies seleccionades i portades a casa nostra des de els punts més remots del món; infusions i tes i les seves barreges exclusives, llegums, farines i molt més...\xa0<br />\nAl nostre comerç hi trobareu productes de cultiu ecològic i de proximitat. L'agricultura i el comerç responsable tenen per nosaltres una importància màxima.\xa0<br />\n\xa0",
#   'web': 'http://www.pastaigra.com',
#   'adress': 'Carrer Providència, 152',
#   'district': 'Gràcia',
#   'neighbourhood': "Camp d'en Grassot i Gràcia Nova",
#   'location': "('41,40964750', '2,16253660')",
#   'type': 'restaurant'},
#  {'shopname': 'New Fitness',
#   'description': 'Dietètica i nutrició esportiva.<br />\nProductes ecològics.',
#   'web': 'https://www.newfitnessairesur.com/horarios',
#   'adress': 'Bac de Roda, 194-196',
#   'district': 'Sant Martí',
#   'neighbourhood': 'Sant Martí de Provençals',
#   'location': "('41,41495040', '2,19441340')",
#   'type': 'alimentation'},
#  {'shopname': 'Superverd Huelva',
#   'description': "Fruiteria amb venda de productes d'alimentació ecològics i a granel.<br />\n<br />\nSuperverd és una empresa d’origen català, dedicada a la venda de fruita i verdura al detall. Creada a mitjans dels anys 80, Superverd compta actualment amb més de 85 establiments repartits per tot el territori català.<br />\n<br />\nEl nostre objectiu és oferir als nostres clients les millors fruites i verdures en cada moment, garantint sempre la seva qualitat. A les nostres botigues el client gaudirà del millor servei i de la professionalitat que ens caracteritza.",
#   'web': 'http://www.superverd.es/',
#   'adress': 'Carrer Huelva, 48',
#   'district': 'Sant Martí',
#   'neighbourhood': 'Sant Martí de Provençals',
#   'location': "('41,41639660', '2,19505890')",
#   'type': 'vegan food'},
#  {'shopname': 'Frescuore Maresme',
#   'description': "Fruiteria amb selecció de productes d'alimentació ecològics.",
#   'web': 'https://www.calfruitos.com/es/tiendas',
#   'adress': 'Maresme, 238',
#   'district': 'Sant Martí',
#   'neighbourhood': 'La Verneda i la Pau',
#   'location': "('41,42086780', '2,20459380')",
#   'type': 'beverages'},
#  {'shopname': 'Frescuore Puigcerdà',
#   'description': "Fruiteria amb selecció de productes ecològics: fruita, verdura i altres productes d'alimentació.",
#   'web': 'https://www.calfruitos.com/botigues',
#   'adress': 'Puigcerdà, 211',
#   'district': 'Sant Martí',
#   'neighbourhood': 'La Verneda i la Pau',
#   'location': "('41,41887040', '2,20462930')",
#   'type': 'local food'},
#  {'shopname': 'Frescuore Agricultura',
#   'description': "Fruiteria amb selecció de productes d'alimentació ecològics i a granel.",
#   'web': 'http://www.frescuore.com',
#   'adress': 'Agricultura, 211',
#   'district': 'Sant Martí',
#   'neighbourhood': 'Sant Martí de Provençals',
#   'location': "('41,41650460', '2,20322930')",
#   'type': 'restaurant'},
#  {'shopname': 'Natura Espai Ecològic',
#   'description': "La botiga BIO des de l'any 1973 a Gràcia.<br />\nHerbolari, dietètica, alimentació biològica, productes a granel biològics i productes de comerç just.",
#   'web': '',
#   'adress': "Torrent de l'Olla, 92",
#   'district': 'Gràcia',
#   'neighbourhood': 'Vila de Gràcia',
#   'location': "('41,40110590', '2,15878080')",
#   'type': 'bakery'},
#  {'shopname': 'Dishome Sant Andreu',
#   'description': "Productes amb certificats ecolabel, ecologylabel i registre alimentari.<br />\nReutilització d'envasos per reomplir amb un sistema de bossetes fetes amb film de blat de moro 100% hidrosoluble.<br />\nNeteja professional amb producte actius del 28 al 40%.",
#   'web': 'www.disarp.com   www.dishome.es    www.dreamgold.es',
#   'adress': 'Carrer Sócrates, 73',
#   'district': 'Sant Andreu',
#   'neighbourhood': 'Sant Andreu',
#   'location': "('41,43188320', '2,18537480')",
#   'type': 'others'},
#  {'shopname': 'Farmàcia Franquesa',
#   'description': 'Farmàcia amb productes elaborats a la pròpia farmàcia.\xa0Cosmètica natural de producció pròpia basada en olis vegetals; tenen compreses de cotó orgànic.<br />\nTreballen amb el laboratori "prodeco", que utilitza productes ecològics.',
#   'web': 'http://www.1842.cat/',
#   'adress': 'Carrer Gran de Sant Andreu, 260',
#   'district': 'Sant Andreu',
#   'neighbourhood': 'Sant Andreu',
#   'location': "('41,43514320', '2,18989670')",
#   'type': 'beverages'},
#  {'shopname': 'La Botiga Ecològica',
#   'description': "<br />\nAlimentació biològica i natural<br />\nFruita i verdura - 3 cops per setmana :: Carn i pollastre - cada dimecres.<br />\nVins, caves i cerveses... Tot amb aval biològic de garantia.<br />\nHerboristeria i Dietètica<br />\nMés de 225 plantes al seu abast. Àmplia selecció de tes i espècies a granel.<br />\nAlimentació Macrobiòtica i Natural<br />\nCosmètica i Higiene<br />\nNutrició esportiva<br />\nProductes del Comerç Just<br />\nLa botiga ecològica consta de consulta i cabina de massatges:<br />\nConsulta:<br />\nNaturopatia · Homeopatia · Acupuntura · Dietista (obesitat, diabetes, colesterol, etc.)<br />\nFlors de Bach (pors, inseguretats, insomni, etc.) · Reiki · Psicoteràpia hipnòtica<br />\nTractaments:<br />\nMassatges terapèutics · Reflexoteràpia · Tractaments del dolor<br />\nA la botiga ecològica, en el pís superior, hi trobarà una rèplica d'antic herbolari,<br />\non es troben exposades totes les plantes, tes i espècies que trobarà a la botiga,<br />\naixí com també, la possibilitat de degustar aquella infusió o te que vulgui.<br />\n\xa0",
#   'web': 'http://www.sant-andreu.com/com-2/botigaecologica/index.html',
#   'adress': 'Carrer Gran de Sant Andreu, 242',
#   'district': 'Sant Andreu',
#   'neighbourhood': 'Sant Andreu',
#   'location': "('41,43478265', '2,18917917')",
#   'type': 'supermarket'},
#  {'shopname': 'Equivalenza Sant Andreu',
#   'description': "Venda de perfums a granel, si es reutilitza l'envàs es descompta 1€. Cosmètica sense parabens i vegana (no testada en animals). La fabricació dels seus productes es realitza a Barcelona.<br />\nNo donen bossa, s'embolica en paper, si demanen la bossa donen una de paper.\xa0",
#   'web': 'http://www.equivalenza.com',
#   'adress': 'Gran de Sant Andreu, 225bis',
#   'district': 'Sant Andreu',
#   'neighbourhood': 'Sant Andreu',
#   'location': "('41,43435747', '2,18930364')",
#   'type': 'restaurant'},
#  {'shopname': 'Els Ous de la Sandra',
#   'description': "Venda d'ous a granel i ous ecològics.",
#   'web': '',
#   'adress': 'Mercat de Sant Andreu. Parada 120-121',
#   'district': 'Sant Andreu',
#   'neighbourhood': 'Sant Andreu',
#   'location': "('41,43482741', '2,18839089')",
#   'type': 'beverages'},
#  {'shopname': 'Centre Dietètic Sant Andreu',
#   'description': 'Dietètica amb productes ecològics i suplements dietètics.',
#   'web': 'http://centredieteticsantandreu.com/',
#   'adress': 'Gran de Sant Andreu, 133',
#   'district': 'Sant Andreu',
#   'neighbourhood': 'Sant Andreu',
#   'location': "('41,43148980', '2,18928570')",
#   'type': 'local food'},
#  {'shopname': 'Cal Garrí',
#   'description': "Xarcuteria de productes gourmet. Els seus proveïdors de productes frescos són elaboradors artesanals. Els embotits i formatges són de petits elaboradors, tot de proximitat i de Catalunya.<br />\nTambé tenen formatges ecològics i ous de gallines campestres.\xa0<br />\nDisposen d'un cartell informatiu que recorda que els clients poden portar las eva carmanyola.",
#   'web': 'https://elrosal.cat/es/comestibles/elrosal/on-comprar-les-nostres-galetes/35093/cal-garri/656.html',
#   'adress': 'Carrer de Sicília, 113',
#   'district': 'Eixample',
#   'neighbourhood': 'Fort Pienc',
#   'location': "('41,39617320', '2,18036100')",
#   'type': 'vegan food'},
#  {'shopname': 'Dietètica 46',
#   'description': 'Productes ecològics<br />\nAliments per a tot tipus de dietes<br />\nHerboristeria<br />\nComplements dietètics<br />\nCosmètica natural',
#   'web': '',
#   'adress': 'Gran Via, 691-693 (parada 46 mercat)',
#   'district': 'Eixample',
#   'neighbourhood': 'Fort Pienc',
#   'location': "('41,39697830', '2,17789830')",
#   'type': 'green space'},
#  {'shopname': 'EMI & CARLES',
#   'description': "Botiga d'aliments naturals de denominació d'origen especialitzada en carns i embotits directes de granja. Carn ecològica, embotits de qualitat, bona part del producte de proximitat.<br />\nPel que fa a l'envàs, admeten compra amb carmanyola del client, i tenen safates de canya de sucre.",
#   'web': '',
#   'adress': 'Gran Via, 687',
#   'district': 'Eixample',
#   'neighbourhood': 'Fort Pienc',
#   'location': "('41,39691400', '2,17771020')",
#   'type': 'beverages'},
#  {'shopname': 'ÀGORA llibreria - papereria',
#   'description': 'Papereria on adquirir paper i llibretes de paper reciclat, joguines sense piles, bolígrafs i marcadors recarregables i recanvis. Realitzen fotocòpies en paper reciclat certificat i, a més, recull cartutxos de tòner per reciclar.',
#   'web': 'https://www.compraeixample.cat/es/socio/papereria-agora',
#   'adress': 'Carrer de los Castillejos, 181',
#   'district': 'Eixample',
#   'neighbourhood': 'Fort Pienc',
#   'location': "('41,40214370', '2,18377610')",
#   'type': 'restaurant'},
#  {'shopname': 'RE-CYCLING',
#   'description': 'Botiga de bicicletes de 2a mà.<br />\n<br />\n"Tenim el somni d\'aconseguir que cap bicicleta mori, reciclant qualsevol bicicleta utilitzada. El nostre projecte és poder oferir-te un lloc on puguis vendre la teva bicicleta usada o bé poder comprar una bicicleta de segona mà perfectament preparada".',
#   'web': 'https://www.somosrecycling.es',
#   'adress': 'Marina, 127',
#   'district': 'Eixample',
#   'neighbourhood': 'Fort Pienc',
#   'location': "('41,39667607', '2,18405461')",
#   'type': 'others'},
#  {'shopname': 'Salut Natural Herbodietètica',
#   'description': 'Salut Natural és un herbolari des de 1983. Són especialistes en Dietoteràpia (a partir del aliments del dia a dia es poden fer grans millores!).<br />\nVenen herbes a granel i tenen alimentació i productes de neteja amb certificació ecològica.',
#   'web': 'https://www.herbolarisalutnatural.com/',
#   'adress': 'Casp, 139',
#   'district': 'Eixample',
#   'neighbourhood': 'Fort Pienc',
#   'location': "('41,39725510', '2,18101700')",
#   'type': 'others'},
#  {'shopname': 'Gran Vida Herbolari',
#   'description': "Botiga especialitzada en cosmètica i higiene íntima femenina natural i ecològica. Compreses de roba, copes menstruals, esponges marines.<br />\nEspecialització en embarassades i nadons.<br />\nDisposen de gran varietat de plantes medicinals a granel. També ofereixen una àmplia gamma d'espècies, selecció de tes, complements alimentaris, productes apícoles (mel, pol·len i pròpolis), aliments naturals procedents d'agricultura ecològica, aliments dietètics i de règim especial (sense gluten, sense sucre, vegans, etc.).<br />\n<br />\n\xa0",
#   'web': 'https://herbolarigranvida.com/',
#   'adress': 'Gran Via, 748',
#   'district': 'Eixample',
#   'neighbourhood': 'Fort Pienc',
#   'location': "('41,39754479', '2,17947043')",
#   'type': 'local food'},
#  {'shopname': 'Cal Fruitós',
#   'description': "A la botiga es poden trobar fruita i verdura ecològica i de proximitat, a més d'una llista llarga de productes per contribuir a la dieta mediterrània, com l’oli d’olives arbequines de Siurana, productes del dia a dia com l’aigua de la Garrotxa o el vi de Falset, productes sense gluten, capritxos diaris sense sucre o endolcits amb sucre vegetal com l’ Stevia, i altres productes procedents de famílies que produeixen productes artesans de màxima qualitat, com el làctics artesans de Sallent o l’arròs de Pals.",
#   'web': 'http://www.calfruitos.com',
#   'adress': 'Nàpols, 113',
#   'district': 'Eixample',
#   'neighbourhood': 'Fort Pienc',
#   'location': "('41,39511253', '2,17961470')",
#   'type': 'others'},
#  {'shopname': 'Ferreteria Racavi',
#   'description': "Botiga on es poden adquirir productes de ferreteria a granel, bombetes de baix consum i LEDS, estalviadors d'aigua, carregadors i piles recarregables, paelles amb recobriment ecològic, etc.",
#   'web': 'https://www.qdq.com/ferreteria-racavi-760975',
#   'adress': "Carrer d'Ausiàs Marc, 113",
#   'district': 'Eixample',
#   'neighbourhood': 'Fort Pienc',
#   'location': "('41,39564372', '2,18130986')",
#   'type': 'supermarket'},
#  {'shopname': 'Fruiteria La Gripaueta',
#   'description': 'Fruiteria i verduleria. Inclou oferta ecològica de producte de proximitat i de fora: fruita, verdura, ous, llegums.',
#   'web': '',
#   'adress': 'Constança 8-10',
#   'district': 'Les Corts',
#   'neighbourhood': 'Les Corts',
#   'location': "('41,38805689', '2,13602541')",
#   'type': 'alimentation'},
#  {'shopname': 'Wine palace',
#   'description': "Bodega amb oferta de vins ecològics i biodinàmics. A més d'altres destil·lats en ampolla i a granel.\xa0",
#   'web': 'http://www.winepalace.es',
#   'adress': 'Avinguda Sarrià 30',
#   'district': 'Les Corts',
#   'neighbourhood': 'Les Corts',
#   'location': "('41,39070210', '2,14314040')",
#   'type': 'beverages'},
#  {'shopname': 'Fent punt',
#   'description': 'Merceria. Venda de llanes, reutilització de roba, venda de pedaços, teles i productes de merceria',
#   'web': '',
#   'adress': 'Gran Via de Carles III, 46- 48',
#   'district': 'Les Corts',
#   'neighbourhood': 'Les Corts',
#   'location': "('41,38283149', '2,12874595')",
#   'type': 'supermarket'},
#  {'shopname': "Un mar d'idees",
#   'description': 'Papereria, copisteria, impressió digital, arts gràfiques',
#   'web': 'http://www.unmardidees.com',
#   'adress': 'Joan Güell, 142',
#   'district': 'Les Corts',
#   'neighbourhood': 'Les Corts',
#   'location': "('41,38263995', '2,13164846')",
#   'type': 'others'},
#  {'shopname': 'Les Corts natural',
#   'description': "Productes certificats d'alimentació i cosmètica eco i bio, tenen bossa de paper",
#   'web': 'https://www.naturopatia-rosagarcia.es/les-corts-natural/',
#   'adress': 'Vallespir, 169',
#   'district': 'Les Corts',
#   'neighbourhood': 'Les Corts',
#   'location': "('41,38388700', '2,13397910')",
#   'type': 'green space'},
#  {'shopname': 'Bloi moda ecològica',
#   'description': 'Moda eco amb teixit certificat, disseny i producció pròpia. Cotó orgànic, sense químics, producció ètica. Bossa de paper.',
#   'web': 'http://www.bloi.es',
#   'adress': 'Carrer Guitard, 71',
#   'district': 'Les Corts',
#   'neighbourhood': 'Les Corts',
#   'location': "('41,38410660', '2,13636570')",
#   'type': 'beverages'},
#  {'shopname': 'B69 ferreteria',
#   'description': "Ferreteria amb oferta de productes ecològics (bombetes de baix consum, estalviadors d'aigua). Venta de productes a granel (cargols, arandeles...).",
#   'web': '',
#   'adress': 'Berlín, 69',
#   'district': 'Les Corts',
#   'neighbourhood': 'Les Corts',
#   'location': "('41,38377360', '2,13972120')",
#   'type': 'others'},
#  {'shopname': 'Herbolari Milfulles',
#   'description': 'Productes dietètics, alimentació i infusions. Productes de proximitat i ecològics (fruita, verdura, mel, ous). Infusions i fruits secs a granel. Cosmètica bio. Pa ecològic.',
#   'web': 'https://www.santmartieix.com/cat/soci/herbolari-milfulles',
#   'adress': 'c/ Agricultura, 252',
#   'district': 'Sant Martí',
#   'neighbourhood': 'Sant Martí de Provençals',
#   'location': "('41,41846480', '2,20101440')",
#   'type': 'green space'},
#  {'shopname': 'Bodega Andrade',
#   'description': "Bodega. Oferta de vins a granel, sifó retornable, licors i caves. Part de l'oferta de vins de proximitat.",
#   'web': 'http://bodegasandrade.es/',
#   'adress': "Carrer d'Andrade, 159",
#   'district': 'Sant Martí',
#   'neighbourhood': 'Sant Martí de Provençals',
#   'location': "('41,41671560', '2,20189800')",
#   'type': 'alimentation'},
#  {'shopname': 'La dietética',
#   'description': "Botiga d'alimentació ecològica, herbodietética, cosmética bio",
#   'web': '',
#   'adress': 'Maresme 202-208',
#   'district': 'Sant Martí',
#   'neighbourhood': 'La Verneda i la Pau',
#   'location': "('41,41955370', '2,20635360')",
#   'type': 'supermarket'},
#  {'shopname': 'Amapola bio cosmètics',
#   'description': 'Botiga de productes de cosmètica ecològics, orgànics i bio amb certificació',
#   'web': 'http://www.amapolabio.com',
#   'adress': 'Bòria 20',
#   'district': 'Ciutat Vella',
#   'neighbourhood': 'Sant Pere, Santa Caterina i la Ribera',
#   'location': "('41,38453020', '2,17896500')",
#   'type': 'supermarket'},
#  {'shopname': 'Pirineu en boca',
#   'description': "Productes gastronòmics del Pirineu; carns\xa0 directament del productor al consumidor d'animals criats en entorns naturals de manera respectuosa amb el medi ambient. Tenen una selecció de productes ecològics: formatges, dolços, embotits.",
#   'web': 'http://www.pirineuenboca.com/',
#   'adress': 'Carrer de Girona, 17',
#   'district': 'Eixample',
#   'neighbourhood': "Dreta de l'Eixample",
#   'location': "('41,39152920', '2,17509430')",
#   'type': 'vegan food'},
#  {'shopname': 'Cal Rosset',
#   'description': 'Botiga de venda de fruita i verdura ecològica, part de la qual és de producció pròpia. Tenen camps a Sant Viçents dels Horts i a Sant Boi de Llobregat. Tots els productes són ecològics i de proximitat.',
#   'web': 'http://www.calrosset.com',
#   'adress': 'Carrer de Nàpols, 155',
#   'district': 'Eixample',
#   'neighbourhood': "Dreta de l'Eixample",
#   'location': "('41,39718030', '2,17684580')",
#   'type': 'local food'},
#  {'shopname': 'Biobarri',
#   'description': 'Botiga amb productes alimentaris biològics i ecològics. També tenen una bona varietat de productes de cosmètica i neteja ecològics. Ofereixen una selecció de productes frescos de proximitat',
#   'web': 'https://www.lovkombucha.com/es/bio-barri/',
#   'adress': 'Mendez Núñez, 18',
#   'district': 'Eixample',
#   'neighbourhood': "Dreta de l'Eixample",
#   'location': "('41,39039440', '2,17724860')",
#   'type': 'green space'},
#  {'shopname': 'Celler Nulles',
#   'description': 'Celler amb oferta de vins ecològics, a granel\xa0 i de proximitat. Tenen oferta de productes amb envàs retornable',
#   'web': 'http://www.cellernulles.com',
#   'adress': 'Nàpols 239',
#   'district': 'Eixample',
#   'neighbourhood': "Dreta de l'Eixample",
#   'location': "('41,40063140', '2,17227810')",
#   'type': 'local food'},
#  {'shopname': 'Obowylu fruites i verdures',
#   'description': 'Botiga de venda de fruites i verdures ecològiques. Tenen productes de proximitat, selecció de conserves i cereals ecològics',
#   'web': '',
#   'adress': 'Carrer de Roger de Flor, 202',
#   'district': 'Eixample',
#   'neighbourhood': "Dreta de l'Eixample",
#   'location': "('41,39907160', '2,17246180')",
#   'type': 'beverages'},
#  {'shopname': 'Ecocentre',
#   'description': 'Supermercat de productes ecològics. Tenen varietat de productes aptes per a vegans, cosmètica i neteja',
#   'web': 'www.ecocentre.cat',
#   'adress': 'Avinguda Diagonal, 329',
#   'district': 'Eixample',
#   'neighbourhood': "Dreta de l'Eixample",
#   'location': "('41,39874900', '2,16938400')",
#   'type': 'local food'},
#  {'shopname': 'Carnisseria Canals',
#   'description': "Carnisseria amb selecció de carn de pollastre i vedella ecològiques. Ofereixen una selecció de begudes i productes d'alimentació ecològics",
#   'web': '',
#   'adress': 'Passeig Sant Joan, 114',
#   'district': 'Eixample',
#   'neighbourhood': "Dreta de l'Eixample",
#   'location': "('41,40019000', '2,16910470')",
#   'type': 'bakery'},
#  {'shopname': 'El rebost de Sant Andreu',
#   'description': 'Venda de productes a granel, amb sel·lecció de productes ecológics, de proximitat, locals, socials i sostenibles. Vins a granel de proximitat amb sistema de dipósit d\'envasos. Llegums cuits a diari. Ous ecológics, de gallines felices del Montseny. Mel crua del Perelló a granel. Directa de l\'apicultor. Gran sel·lecció de tes i herbes a granel. Cistella de verdura de temporada directa de pagès. Cuinats propis. Sabons líquids i detergents en escates a granel. Botiga zero residu, on no es ven cap producte envasat en plástic i es fomenta l\'ús d\'envasos reutilitzables, com pots de vidre.\xa0Han incorporat una nova mesura de reutilització; els "envasos orfe", això consisteix en què els clients poden portar envasos que no facin servir, passen per un procés d\'higienització i futurs clients poden donar una 2a vida a aquests envasos.',
#   'web': 'https://esloqueveo.com/el_rebost_de_sant_andreu_barcelona_barcelona_espana-153595-en.html',
#   'adress': 'Gran de Sant Andreu, 327',
#   'district': 'Sant Andreu',
#   'neighbourhood': 'Sant Andreu',
#   'location': "('41,43739730', '2,18921620')",
#   'type': 'others'},
#  {'shopname': 'Diet center',
#   'description': 'Botiga amb venda de productes ecològics, biològics i orgànics. Ofereixen suplements nutricionals, productes de neteja i cosmètica ecològics.\xa0',
#   'web': 'www.dietcenter.es',
#   'adress': 'Joan Güell, 170',
#   'district': 'Les Corts',
#   'neighbourhood': 'Les Corts',
#   'location': "('41,38390110', '2,13113160')",
#   'type': 'beverages'},
#  {'shopname': 'Laboratorio Aurum cosmètic',
#   'description': 'Centre de cosmètica ecològica. Comercialització de productes de fabricació pròpia a navarra (no els fabriquen a barcelona però els fan ells mateixos a navarra).',
#   'web': 'http://www.aurumcosmetic.com/-.html',
#   'adress': 'Lepant, 311',
#   'district': 'Eixample',
#   'neighbourhood': 'Sagrada Família',
#   'location': "('41,40661400', '2,17362610')",
#   'type': 'beverages'},
#  {'shopname': 'Bio Món',
#   'description': "Botiga d’alimentació ecològica. Fruita i verdura de proximitat (vilassar de mar). Selecció de cosmètica i neteja eco i begudes eco. Venta d'aigua de Sant Aniol en envàs de vidre retornable. Copa menstrual.",
#   'web': 'https://biomon.es/',
#   'adress': 'Carrer Cartagena, 317',
#   'district': 'Eixample',
#   'neighbourhood': 'Sagrada Família',
#   'location': "('41,41071740', '2,17474790')",
#   'type': 'bakery'},
#  {'shopname': 'Xeito papereria',
#   'description': 'Papereria i llibreria. Tenen oferta de paper reciclat per a imprimir i llibretes de paper reciclat, a més tenen productes recarregables.',
#   'web': 'https://www.regalabien.com/librerias/libreriapapeleria-xeito-en-rossello-384-barcelona',
#   'adress': 'Roselló, 384',
#   'district': 'Eixample',
#   'neighbourhood': 'Sagrada Família',
#   'location': "('41,40467160', '2,17262510')",
#   'type': 'bakery'},
#  {'shopname': 'Molsa',
#   'description': "Supermercat de productes ecològics i biològics. Tenen oferta d'alimentació, begudes, neteja, cosmètica i productes a granel i de proximitat",
#   'web': 'http://molsa.bio',
#   'adress': 'Carrer de Padilla, 264',
#   'district': 'Eixample',
#   'neighbourhood': 'Sagrada Família',
#   'location': "('41,40672730', '2,17602100')",
#   'type': 'restaurant'},
#  {'shopname': 'Patchcat',
#   'description': "Botiga amb venda d'estris i elements per a fer patchwork i manualitats.<br />\nFan reutilització de roba, cursos de recuperació de mobles, reutilització de caixes, confecció de bosses,... que després poden vendre. Fan bosses de cotó per vendre la guata i reutilitzar en properes compres. Tenen fil de cotó bio per teixir i de cotó 100%.",
#   'web': '',
#   'adress': 'València 431',
#   'district': 'Eixample',
#   'neighbourhood': 'Sagrada Família',
#   'location': "('41,40244950', '2,17585810')",
#   'type': 'others'},
#  {'shopname': 'Bureau Vallée',
#   'description': 'Tenen llibretes de paper reciclat, tòner eco i llapis eco. Carpetes i carpesans a partir de paper reciclat, col·lecció de motxilles i estoigs "save the ocean", elaborats a partir de plàstic del mar reciclat. Bolígrafs de plàstic reciclat d\'ampolles.',
#   'web': 'http://bureau-vallee.es/barcelona-sagrada-familia/',
#   'adress': 'Provença 504',
#   'district': 'Eixample',
#   'neighbourhood': 'Sagrada Família',
#   'location': "('41,40660770', '2,17749890')",
#   'type': 'beverages'},
#  {'shopname': 'Pura vida',
#   'description': "Botiga d'herbodietètica i osteopatia. Tenen aliments biològics i cosmètica bio. Medicina fitoterapèutica i ortomolecular",
#   'web': 'https://shencorpore.es',
#   'adress': 'Carrer de Cartagena, 222',
#   'district': 'Eixample',
#   'neighbourhood': 'Sagrada Família',
#   'location': "('41,40668760', '2,18043570')",
#   'type': 'supermarket'},
#  {'shopname': 'El graner',
#   'description': "Tenen producte a granel, tant d'alimentació com neteja, també tenen selecció de productes eco i bio. Algun producte de comerç just. Afavoreixen portar l'envàs amb un descompte.",
#   'web': 'https://elgraner.food.blog/',
#   'adress': 'Provença 495',
#   'district': 'Eixample',
#   'neighbourhood': 'Sagrada Família',
#   'location': "('41,40676810', '2,17734380')",
#   'type': 'beverages'},
#  {'shopname': 'Lettuce family',
#   'description': 'Botiga de venda de fruita i verdura amb selecció de productes ecològics i de proximitat',
#   'web': 'http://www.lettucefamily.com',
#   'adress': 'Astúries, 8',
#   'district': 'Gràcia',
#   'neighbourhood': 'Vila de Gràcia',
#   'location': "('41,40271860', '2,15335250')",
#   'type': 'bakery'},
#  {'shopname': 'La mama vaca',
#   'description': 'Botiga de criança sostenible. Productes de puericultura. Fan tallers i activitats pre i post part. Tenen selecció de productes de cosmètica bio i natural, km 0, bolquers reutilitzables i recanvis, roba de cotó orgànic, selecció vaixella eco i calçat vegà.<br />\n<br />\nAutomatically translated with Google Translate API.<br />\n\xa0',
#   'web': 'http://www.lamamavaca.com',
#   'adress': 'Rambla del Prat, 25',
#   'district': 'Gràcia',
#   'neighbourhood': 'Vila de Gràcia',
#   'location': "('41,40106300', '2,15153990')",
#   'type': 'supermarket'},
#  {'shopname': 'De tela',
#   'description': 'Botiga especialitzada en venda de bolquers de tela reutilitzables. Ecocriança i comètica bio',
#   'web': 'http://detela.cat',
#   'adress': 'Carrer de Puigmartí, 48',
#   'district': 'Gràcia',
#   'neighbourhood': 'Vila de Gràcia',
#   'location': "('41,40235850', '2,16081490')",
#   'type': 'green space'},
#  {'shopname': 'Vinoteca de Gràcia. Wine Palace',
#   'description': 'Botiga de venda de vins orgànics. Tenen selecció de vins a granel i embotellats. Amb ampolles i garrafes de retorn de vidre',
#   'web': 'https://www.winepalace.es/es/tiendas/544000024/vinoteca-de-gracia-by-wine-palace',
#   'adress': 'Verdi, 67',
#   'district': 'Gràcia',
#   'neighbourhood': 'Vila de Gràcia',
#   'location': "('41,40479310', '2,15576690')",
#   'type': 'bakery'},
#  {'shopname': 'Rekup & Co',
#   'description': 'Botiga de venda de mobles de fusta recuperada. Productes de decoració. Tot reciclat',
#   'web': 'https://www.rekupandco.com',
#   'adress': 'Carrer de Verdi, 63',
#   'district': 'Gràcia',
#   'neighbourhood': 'Vila de Gràcia',
#   'location': "('41,40465300', '2,15591600')",
#   'type': 'supermarket'},
#  {'shopname': 'La besnéta',
#   'description': 'Botiga de venda de pastisseria vegana. Tots els productes són de producció pròpia. Fan servir farines ecològiques i fruita de proximitat. Tenen selecció de begudes i melmelades de proximitat. Tot vegà',
#   'web': 'http://www.labesneta.com',
#   'adress': 'Torrijos, 37',
#   'district': 'Gràcia',
#   'neighbourhood': 'Vila de Gràcia',
#   'location': "('41,40387340', '2,15826510')",
#   'type': 'others'},
#  {'shopname': 'EcoLògic',
#   'description': 'Botiga de venda de productes frescos ecològics. Tenen fruita i verdura de proximitat i begudes eco',
#   'web': 'http://www.eco-logic.cat',
#   'adress': 'Plaça de la llibertat, 6',
#   'district': 'Gràcia',
#   'neighbourhood': 'Vila de Gràcia',
#   'location': "('41,40009150', '2,15370130')",
#   'type': 'others'},
#  {'shopname': 'Gra de Gràcia Astúries',
#   'description': 'Botiga de venda de producte a granel de proximitat i ecològic. Ofereixen envasos biodegradables, bosses de paper o envasos de vidre i bosses de roba reutilitzables. Més l’opció de portar el propi envàs i tenir descompte. També tenen begudes i productes aptes per intoleràncies alimenticies.\xa0',
#   'web': 'https://gradegracia.cat',
#   'adress': 'Astúries, 26',
#   'district': 'Gràcia',
#   'neighbourhood': 'Vila de Gràcia',
#   'location': "('41,40321440', '2,15418600')",
#   'type': 'beverages'},
#  {'shopname': 'Gra de Gràcia Puigmartí',
#   'description': 'Botiga de venda de producte a granel de proximitat i ecològic. Ofereixen envasos biodegradables, bosses de paper o envasos de vidre i bosses de roba reutilitzables. Més l’opció de portar el propi envàs i tenir descompte. També tenen begudes i productes aptes per intoleràncies alimenticies.\xa0',
#   'web': 'https://gradegracia.cat',
#   'adress': 'Puigmartí, 11',
#   'district': 'Gràcia',
#   'neighbourhood': 'Vila de Gràcia',
#   'location': "('41,40153040', '2,15905450')",
#   'type': 'restaurant'},
#  {'shopname': 'Artipà',
#   'description': 'Botiga de venda de pa i pastisseria fets amb farines ecològiques i aptes per a intoleràncies alimenticies',
#   'web': 'http://www.artipa.cat',
#   'adress': 'Travassera de Gràcia, 245',
#   'district': 'Gràcia',
#   'neighbourhood': 'Vila de Gràcia',
#   'location': "('41,40416440', '2,16211450')",
#   'type': 'others'},
#  {'shopname': 'Agrícola Mau',
#   'description': 'Fruiteria i verduleria ecològica. Selecció de productes eco',
#   'web': '',
#   'adress': 'Mare de déu dels desamparats, 25',
#   'district': 'Gràcia',
#   'neighbourhood': 'Vila de Gràcia',
#   'location': "('41,40236330', '2,15845830')",
#   'type': 'others'},
#  {'shopname': 'Les biològiques',
#   'description': 'Botiga de venda de productes d’alimentació ecològics, de proximitat i a granel, fitoteràpia, criança natural, bolquers de roba i copes menstruals i sabons ecològics a granel.\xa0',
#   'web': '',
#   'adress': 'Milà i Fontanals, 33',
#   'district': 'Gràcia',
#   'neighbourhood': 'Vila de Gràcia',
#   'location': "('41,40150600', '2,16195420')",
#   'type': 'supermarket'},
#  {'shopname': 'Carnisseria Diego',
#   'description': "Botiga de venda de carn ecològica. Tenen vedella, xai i pollastre. Hamburgueses d'elaboració pròpia",
#   'web': '',
#   'adress': 'Puigmartí, 5',
#   'district': 'Gràcia',
#   'neighbourhood': 'Vila de Gràcia',
#   'location': "('41,40137600', '2,15881330')",
#   'type': 'vegan food'},
#  {'shopname': 'Mina mina workshop',
#   'description': 'Botiga de venda de teles. Tenen cotons orgànics estampats i fan tallers de reaprofitament',
#   'web': 'http://minaminero.blogspot.com/',
#   'adress': 'Plaça de la Virreina, 7',
#   'district': 'Gràcia',
#   'neighbourhood': 'Vila de Gràcia',
#   'location': "('41,40476060', '2,15710420')",
#   'type': 'supermarket'},
#  {'shopname': 'Les 9 fonts',
#   'description': "Centre de teràpies i productes naturals; tenen selecció de productes d'alimentació biològics, fan massatges, tenen cosmètica biològica i natural. Medicina ortomolecular i fitoteràpia.\xa0",
#   'web': 'https://www.les9fonts.com/',
#   'adress': 'Carrer de Casanova, 63',
#   'district': 'Eixample',
#   'neighbourhood': "L'Antiga Esquerra de l'Eixample",
#   'location': "('41,38513670', '2,15900200')",
#   'type': 'local food'},
#  {'shopname': 'Catalunya Freedom',
#   'description': 'Roba de cotó orgànic produïda a Mataró i de disseny propi',
#   'web': 'http://www.catalunyafreedom.cat',
#   'adress': 'Carrer de Mallorca, 197',
#   'district': 'Eixample',
#   'neighbourhood': "L'Antiga Esquerra de l'Eixample",
#   'location': "('41,39017660', '2,15750610')",
#   'type': 'beverages'},
#  {'shopname': 'Strata bakery',
#   'description': "Pastisseria amb productes vegans (pastissos, pastes, empanades) tot d'elaboració pròpia per a emportar.",
#   'web': 'www.stratabakery.com',
#   'adress': 'Carrer de Provença, 158',
#   'district': 'Eixample',
#   'neighbourhood': "L'Antiga Esquerra de l'Eixample",
#   'location': "('41,38789940', '2,15258860')",
#   'type': 'alimentation'},
#  {'shopname': 'Farmàcia provença 156',
#   'description': 'Tenen compreses de cotó orgànic, copa menstrual, linia de cosmètica pròpia i fan fòrmules magistrals.',
#   'web': 'http://www.farmaciaprovenza156.com/es/',
#   'adress': 'Carrer de Provença, 156',
#   'district': 'Eixample',
#   'neighbourhood': "L'Antiga Esquerra de l'Eixample",
#   'location': "('41,38784390', '2,15251480')",
#   'type': 'supermarket'},
#  {'shopname': 'Cloudstreet bakery',
#   'description': "Forn de pa 100 % ecològic. Fan massa mare i tenen forn de llenya. Treballen amb diferents tipus de farines ecològiques i també fan pastes amb un 90% d'ingredients ecològics.",
#   'web': 'https://www.cloudstreet.es/',
#   'adress': 'Carrer del Rosselló, 112',
#   'district': 'Eixample',
#   'neighbourhood': "L'Antiga Esquerra de l'Eixample",
#   'location': "('41,38847000', '2,15108800')",
#   'type': 'bakery'},
#  {'shopname': 'BioPompas El Ninot',
#   'description': "Productes de neteja per a la llar, detergents, higiene i cura personal i rentat de roba biodegradables a granel amb envasos reutilitzables. També tenen una linia d'higiene animal, personal i ecològica..",
#   'web': 'https://biopompas.com/',
#   'adress': 'Carrer Mallorca, 150',
#   'district': 'Eixample',
#   'neighbourhood': "L'Antiga Esquerra de l'Eixample",
#   'location': "('41,38770170', '2,15457690')",
#   'type': 'vegan food'},
#  {'shopname': 'Uve-i vinaters',
#   'description': 'Botiga amb venda de vins ecològics, biodinàmics, naturals i de proximitat. Tenen vins envasats en back in box (envasos 5 llitres)',
#   'web': '',
#   'adress': 'Carrer de Casanova, 76',
#   'district': 'Eixample',
#   'neighbourhood': "L'Antiga Esquerra de l'Eixample",
#   'location': "('41,38591050', '2,15827960')",
#   'type': 'beverages'},
#  {'shopname': 'Casa Ruiz Granel Selecto (Aribau)',
#   'description': 'Botiga amb venda a granel de llegums, fruits secs, arrossos, pastes, cereals, grans, farines, sèmoles, espècies, \xa0tes, infusions, llavors, cacaus, xocolata, fruites deshidratades, algues i bolets deshidratats. També tenen selecció de productes ecològics i de proximitat.<br />\nAltres botigues als carrers <a href="https://www.bcnsostenible.cat/web/punt/casa-ruiz-granel-selecto-bruc" target="_blank">Bruc </a>i <a href="https://www.bcnsostenible.cat/web/punt/casa-ruiz-granel-selecto" target="_blank">Muntaner</a>.',
#   'web': 'https://casaruizgranel.com/ca/',
#   'adress': "Carrer d'Aribau, 169",
#   'district': 'Eixample',
#   'neighbourhood': "L'Antiga Esquerra de l'Eixample",
#   'location': "('41,39331370', '2,15238810')",
#   'type': 'beverages'},
#  {'shopname': 'Columpiu',
#   'description': 'Mobles i objectes diversos de segona mà',
#   'web': '',
#   'adress': 'Carrer de Casanova, 159',
#   'district': 'Eixample',
#   'neighbourhood': "L'Antiga Esquerra de l'Eixample",
#   'location': "('41,39115830', '2,15097130')",
#   'type': 'beverages'},
#  {'shopname': 'Vins & Co',
#   'description': "Botiga amb oferta de vins catalans de petita producció; el 100% de l'oferta és de proximitat. Tenen vins ecològics, biodinàmics i naturals.",
#   'web': 'http://www.vinsandco.cat',
#   'adress': "Carrer d'Aribau, 177",
#   'district': 'Eixample',
#   'neighbourhood': "L'Antiga Esquerra de l'Eixample",
#   'location': "('41,39389230', '2,15190030')",
#   'type': 'beverages'},
#  {'shopname': 'Perruqueria Integral Barcelona',
#   'description': 'Perruqueria amb venda de productes naturals i ecològics. Fan tractaments de bellesa i de prerruqueria amb els mateixos productes.',
#   'web': 'https://www.integral.barcelona',
#   'adress': 'Carrer del Comte Borrell, 205',
#   'district': 'Eixample',
#   'neighbourhood': "La Nova Esquerra de l'Eixample",
#   'location': "('41,38520420', '2,15211030')",
#   'type': 'local food'},
#  {'shopname': 'Casa Artesà',
#   'description': "Queviures amb productes d'alimentació 100% ogànics, ecològics i /o biològics. Tenen fruita i verdura de proximitat i ecològica, grans, pasta, farines i llegums a granel, begudes, tes i melmelades ecològiques.",
#   'web': 'https://www.casaartesa.com',
#   'adress': 'Carrer de Rocafort, 109',
#   'district': 'Eixample',
#   'neighbourhood': "La Nova Esquerra de l'Eixample",
#   'location': "('41,37986120', '2,15220180')",
#   'type': 'bakery'},
#  {'shopname': 'Super Orgànic',
#   'description': 'Supermercat de productes ecològics. Tenen articles de cosmètica, neteja, alimentació, fruita i verdura, productes frescos, congelats, làctics, embutits, menjar preparat i hamburgueses vegetals.\xa0',
#   'web': '',
#   'adress': 'Carrer de Llançà, 56',
#   'district': 'Eixample',
#   'neighbourhood': "La Nova Esquerra de l'Eixample",
#   'location': "('41,38059290', '2,14516910')",
#   'type': 'alimentation'},
#  {'shopname': 'Petit pijama',
#   'description': "Botiga infantil especialitzada en pijames. Tenen roba de nadó de cotó orgànic i gairebé tota l'oferta és de proximitat. També venen joguines i contes",
#   'web': 'https://www.petitpijama.com',
#   'adress': 'Roselló 38',
#   'district': 'Eixample',
#   'neighbourhood': "La Nova Esquerra de l'Eixample",
#   'location': "('41,38520330', '2,14677430')",
#   'type': 'alimentation'},
#  {'shopname': 'Granel Eixample',
#   'description': 'Cereals, llegums, gra, farines, pasta, arrossos, fruits secs, olis, ous, algues de proximitat i a granel. Tenen vins, sucs i caves de proximitat. Herbes, deshidratats i tes a granel. També ofereixen fruita i verdura de proximitat de petits productors.\xa0',
#   'web': 'https://granel.cat/ca/',
#   'adress': "Carrer d'Entença, 191",
#   'district': 'Eixample',
#   'neighbourhood': "La Nova Esquerra de l'Eixample",
#   'location': "('41,38508720', '2,14320180')",
#   'type': 'bakery'},
#  {'shopname': 'Fruites Ester',
#   'description': 'Fruites i verdures de proximitat i de temporada',
#   'web': '',
#   'adress': 'Vilamari 35',
#   'district': 'Eixample',
#   'neighbourhood': 'Sant Antoni',
#   'location': "('41,37646590', '2,15214200')",
#   'type': 'supermarket'},
#  {'shopname': 'Roba interior La Torre',
#   'description': 'Roba interior de cotó orgànic i/o de proximitat',
#   'web': '',
#   'adress': 'Plaça Universitat 4',
#   'district': 'Eixample',
#   'neighbourhood': 'Sant Antoni',
#   'location': "('41,38483000', '2,16360000')",
#   'type': 'beverages'},
#  {'shopname': 'Farmàcia Riba',
# ...
#   'type': 'vegan food'},
#  {'shopname': 'La Marieta',
#   'description': '<br />\nComsmètica i complementació natural i ecològica.\xa0',
#   'web': '',
#   'adress': 'Carrer de Verdi, 75',
#   'district': 'Gràcia',
#   'neighbourhood': 'Vila de Gràcia',
#   'location': "('41,40499270', '2,15555160')",
#   'type': 'restaurant'},
#  {'shopname': 'Natural Mediterrani',
#   'description': "<br />\nCosmetica natural i ecològica, augmentant l'oferta a granel i preparen regals residu zero.\xa0",
#   'web': '',
#   'adress': "Carrer d'Astúries, 33",
#   'district': 'Gràcia',
#   'neighbourhood': 'Vila de Gràcia',
#   'location': "('41,40330810', '2,15414990')",
#   'type': 'beverages'},
#  {'shopname': 'Tresors de Tanit',
#   'description': '<br />\ncosmètica natural i amb certificat ecològic',
#   'web': '',
#   'adress': "Carrer d'Astúries, 65",
#   'district': 'Gràcia',
#   'neighbourhood': 'Vila de Gràcia',
#   'location': "('41,40421010', '2,15543370')",
#   'type': 'others'},
#  {'shopname': 'Labperfum',
#   'description': "<br />\nvenda de perfums a granel amb reutilització de l'envàs",
#   'web': '',
#   'adress': "Carrer d'Astúries, 52",
#   'district': 'Gràcia',
#   'neighbourhood': 'Vila de Gràcia',
#   'location': "('41,40379230', '2,15525020')",
#   'type': 'others'},
#  {'shopname': 'La Baldufa',
#   'description': 'Roba de nen petit,alguna de 2a mà i alguna de cotó orgànic certificat. Boc&rolls i bolquers de roba.',
#   'web': '',
#   'adress': 'Carrer del Cigne, 12',
#   'district': 'Gràcia',
#   'neighbourhood': 'Vila de Gràcia',
#   'location': "('41,40061230', '2,15379200')",
#   'type': 'supermarket'},
#  {'shopname': "Gust d'hort",
#   'description': '<br />\nBotiga de fruites i verdures, collita pròpia sense pesticides, i altres productes tots de Tarragona o Lleida.',
#   'web': '',
#   'adress': 'Plaça de la Vila de Gràcia, 19',
#   'district': 'Gràcia',
#   'neighbourhood': 'Vila de Gràcia',
#   'location': "('41,39995700', '2,15747530')",
#   'type': 'bakery'},
#  {'shopname': 'Granja Armengol',
#   'description': '<br />\nVenta de productes làctics directes de granja pròpia de Gurb.',
#   'web': '',
#   'adress': 'Carrer de Puigmartí, 40',
#   'district': 'Gràcia',
#   'neighbourhood': 'Vila de Gràcia',
#   'location': "('41,40209330', '2,16035430')",
#   'type': 'vegan food'},
#  {'shopname': 'Costa Codina',
#   'description': '<br />\nFarmàcia amb cosmètica ecològica (arko pharma), compreses i tampons de cotó orgànic, copa menstrual i vaixella de fibra de bambú per a bebès. Raspall de dents de bambú i pastes de dents veganes.',
#   'web': 'https://www.farmaciacostacodina.com/',
#   'adress': 'Gran Via de les Corts Catalanes, 568',
#   'district': 'Eixample',
#   'neighbourhood': 'Sant Antoni',
#   'location': "('41,38408210', '2,16160970')",
#   'type': 'alimentation'},
#  {'shopname': 'Farmàcia Martínez',
#   'description': '<br />\nCosmètica ecològica, compreses i tampons de cotó orgànic, copa menstrual, raspalls de dents de bambú',
#   'web': '',
#   'adress': 'Gran Via de les Corts Catalanes, 560',
#   'district': 'Eixample',
#   'neighbourhood': 'Sant Antoni',
#   'location': "('41,38346920', '2,16079440')",
#   'type': 'supermarket'},
#  {'shopname': 'Forn Iglesias',
#   'description': '<br />\nForn on el producte es fa amb pa de farines ecològiques.',
#   'web': '',
#   'adress': 'Gran Via de les Corts Catalanes, 464',
#   'district': 'Eixample',
#   'neighbourhood': 'Sant Antoni',
#   'location': "('41,37928750', '2,15526660')",
#   'type': 'alimentation'},
#  {'shopname': 'Larrara Market',
#   'description': "Larrara Market va ser creada a partir d'una idea revolucionària. Una idea rara de trobar en el mercat: sense gluten (apte per a celíacs), vegà/vegetarià, low waste (productes a granel), ecològic, de proximitat. Volem donar suport a la sostenibilitat aportant el nostre gra de sorra, fent bé les coses des del principi. Cal començar a conscienciar-nos que hi ha alguna cosa que està fallant, i aquesta cosa som nosaltres i els nostres hàbits alimentaris. Estem encantades de poder treballar amb empreses que se sumen a la causa i volen ser diferents, rares com nosaltres!",
#   'web': 'www.larraramarket.cat',
#   'adress': 'Plaça Revolució de Setembre 1868, 16',
#   'district': 'Gràcia',
#   'neighbourhood': 'Vila de Gràcia',
#   'location': "('41,40244860', '2,15809000')",
#   'type': 'vegan food'},
#  {'shopname': 'Granel Poblenou',
#   'description': "GRANEL POBLENOU promou la compra responsable, el consum sostenible, la reutilització i la reducció de residus a través de la venda d’alimentació ecològica i de proximitat a granel. La inmensa majoria de productes es venen a granel, en bosses de paper, i s'incentiva als clients i clientes amb un\xa0 descompte si porten els seus envasos de casa.\xa0<br />\n<br />\nHi trobaràs bons consells i productes per una alimentació saludable i conscient, responent a necessitats reals de consum: pasta, arrossos, farines, llegums, fruits secs, cereals, cafès i tes, espècies, deshidratats, herbes… i seguint amb la filosofia zero-waste també hi trobaràs productes per la higiene personal i la neteja de la llar.<br />\n\xa0",
#   'web': 'https://granel.cat/ca/shop/granel-poblenou/',
#   'adress': 'Rambla del Poblenou, 117',
#   'district': 'Sant Martí',
#   'neighbourhood': 'El Poblenou',
#   'location': "('41,40355220', '2,19770580')",
#   'type': 'supermarket'},
#  {'shopname': 'La Eco Tribu',
#   'description': 'A La Ecotribu trobaràs productes de neteja, higiene personal, cosmética i llar respectuosos amb el medi ambient i amb les persones. Venem productes sense tóxics, la majoria amb certificació ecológica, en envasos biodegradables, reutilitzables o retornables, i molts dels nostres productes es venen a granel. A més, tots estàn fabricats de manera ética i prioritzem la proximitat.',
#   'web': 'https://www.laecotribu.com/',
#   'adress': 'Carrer de Laforja, 79',
#   'district': 'Sarrià - Sant Gervasi',
#   'neighbourhood': 'Sant Gervasi - Galvany',
#   'location': "('41,39611880', '2,14489180')",
#   'type': 'supermarket'},
#  {'shopname': 'Abans morta que senzilla',
#   'description': 'La roba i complements que tenim ens distingeix pel seu disseny i qualitat. Articles reconeguts com a ètics, sostenibles i proximitat!. Vesteix amb teixits de cotó, suaus i textures càlides amb un estil natural i elegant tot afavorint la sostenibilitat del nostre planeta.',
#   'web': '',
#   'adress': "Carrer de l'Ajuntament, 22",
#   'district': 'Sant Andreu',
#   'neighbourhood': 'Sant Andreu',
#   'location': "('41,43562710', '2,19014640')",
#   'type': 'green space'},
#  {'shopname': 'Organic Lab Inc',
#   'description': 'ORGANIC LAB INC neix de la necessitat de tenir cura del medi ambient mentre ens cuidem i és el lloc perfecte per gaudir d’una experiència única. Visita la nostra botiga i explora la nostra gamma d’articles de bellesa i cura personal. Esperem veure’t aviat per Organic Lab Inc!<br />\n<br />\nA Organic Lab Inc trobaràs productes naturals i vegans, que et permetran reduir els teus residus tant en toxicitat com en quantitat.',
#   'web': 'https://www.organiclabinc.com/',
#   'adress': 'Carrer de Coroleu, 2',
#   'district': 'Sant Andreu',
#   'neighbourhood': 'Sant Andreu',
#   'location': "('41,43275420', '2,18910950')",
#   'type': 'vegan food'},
#  {'shopname': 'Casa Donoso Gourmet',
#   'description': "Botiga d'alimentació on es poden trobar productes d'alta qualitat respectuosos amb el medi ambient.<br />\nA Casa Donoso hi trobes productes de comerç just, elaboracions de cuina d'aprofitament i prevenció del malbaratament alimentari, vins a granel en envasos reutilitzables, opcions veganes i ecològiques i producte nacional.",
#   'web': 'https://www.casadonoso.es/',
#   'adress': 'Carrer de Malats, 46',
#   'district': 'Sant Andreu',
#   'neighbourhood': 'Sant Andreu',
#   'location': "('41,43625080', '2,18841350')",
#   'type': 'vegan food'},
#  {'shopname': 'Graneria Torras',
#   'description': "Comerç d'alimentació on es pot adquirir tot tipus de producte d'alimentació a granel (llegum sec, cereals, oli, mel, tes, espècies, etc), i altres envasats amb certificació ecològica.",
#   'web': '',
#   'adress': 'Carrer de Joan Torras, 44',
#   'district': 'Sant Andreu',
#   'neighbourhood': 'Sant Andreu',
#   'location': "('41,43767020', '2,19318710')",
#   'type': 'others'},
#  {'shopname': 'Bon Granel',
#   'description': "Tenim una botiga d'alimentació a granel, des de llegums, arrossos, fruits secs, cereals, café, te, vinagres, mel... tan convencionals com ecològics, i cada vegada tenim més productes de proximitat.<br />\n<br />\nLa nostra botiga està pensada per poder fer una compra sostenible i sense generar cap tipus de residus. La nostra filosofía és no generar més residus d'un sol ús fomentant la reutilització d'envasos fent un descompte als clients que portin els seus propis de casa. Sinó, poden fer la seva compra utilitzant bosses reciclades i biodegradables que tenim a la botiga.",
#   'web': 'www.bongranel.es',
#   'adress': 'Carrer de Sants, 143',
#   'district': 'Sants - Montjuïc',
#   'neighbourhood': 'Sants',
#   'location': "('41,37529090', '2,13323080')",
#   'type': 'vegan food'},
#  {'shopname': 'Manantial Drogueria',
#   'description': "Manantial és una drogueria a granel ubicada al barri d'Eixample a Barcelona. Amb aquesta botiga volem contribuir al benestar de les cases, enfortir l'economia local i participar en la cura del medi ambient promovent una forma de consum responsable.<br />\n<br />\nParticipem en la reducció de l'ús de plàstic amb una oferta àmplia de productes a granel distribuïts en envasos reutilitzables: pols per a la neteja, detergent, gel de dutxa, xampús, olis cosmètics… També oferim alternatives als productes d'ús únic i/o fets de plàstic. Aquests productes inclouen articles per a nens, mascotes, papereria, jardineria, cuina, higiene menstrual, lavabo de la llar i higiene personal.<br />\n\xa0",
#   'web': 'http://manantial.cat/',
#   'adress': "Carrer d'Aribau, 138",
#   'district': 'Eixample',
#   'neighbourhood': "L'Antiga Esquerra de l'Eixample",
#   'location': "('41,39150580', '2,15548050')",
#   'type': 'beverages'},
#  {'shopname': 'Salsifí',
#   'description': "Fruiteria i Verduleria d'alimentació ecològica i de proximitat. Seleccionem en primer terme productes de conrreus catalans i en segon terme productes vinguts de la península. Tot i que fem una excepción amb el plàtan de Canàries, a Salsifí no trobaràs aliments frescs de països llunyans per què no té sentit.<br />\n<br />\n<br />\n\xa0",
#   'web': 'https://salsifi.cat/',
#   'adress': 'Carrer de Fluvià, 123',
#   'district': 'Sant Martí',
#   'neighbourhood': 'Provençals del Poblenou',
#   'location': "('41,40953560', '2,20341490')",
#   'type': 'others'},
#  {'shopname': 'Les tisores del Poble9',
#   'description': 'Perruqueria que treballa amb la marca OWAY, que tenen certificaicó biodinàmica i tot els productes són naturals i sense químics. A més, els productes a la venda es poden comprar en envasos de vidre retornables.',
#   'web': '',
#   'adress': "Carrer de l'Amistat, 9-11 ",
#   'district': 'Sant Martí',
#   'neighbourhood': 'El Poblenou',
#   'location': "('41,40001840', '2,20541100')",
#   'type': 'restaurant'},
#  {'shopname': 'Vernita',
#   'description': "Vernita és un estudi de disseny i taller de costura creativa.<br />\nA la botiga es pot trobar roba per nens i nadons i regals diferents, que segueixen criteris de sostenibilitat. Per exemple, la roba és de proximitat i de fabricació responsable (roba de bambú, de cotó orgànic o reciclada), i també hi ha altres elements que incentiven la reutilització com cantimplores, carmanyoles, motxilles fetes amb material reciclat, entre d'altres.<br />\nA més, també es poden trobar productes decoratius fets a mà com garlandes i coixins, i peces tèxtils per als nadons, nens i adults; tot tipus de bosses, foulards, mantes, colls, pitets, tovalloles y fundas.<br />\nI per completar, fan tallers de costura a mida per nens i grans que donen vida a excedents tèxtils.<br />\n\xa0",
#   'web': '',
#   'adress': 'Carrer de Joncar, 27',
#   'district': 'Sant Martí',
#   'neighbourhood': 'El Poblenou',
#   'location': "('41,40109223', '2,20416228')",
#   'type': 'restaurant'},
#  {'shopname': 'Limonada de lavanda',
#   'description': 'A Limonada de lavanda aposten pels productes de cosmètica sostenibles i naturals, amb el propòsit de vendre productes respectuosos amb el medi ambient, i amb productes de cosmètica sòlida com sabons, renta plats o detergents per la roba.<br />\nA més, també fan tallers de sabons naturals i espelmes sense parafines i tenen tots els ingredients a granel perquè després es pugui fer a casa.',
#   'web': 'https://limonadadelavanda.com/',
#   'adress': 'Carrer Marià Aguiló, 60',
#   'district': 'Sant Martí',
#   'neighbourhood': 'El Poblenou',
#   'location': "('41,40206599', '2,20180193')",
#   'type': 'vegan food'},
#  {'shopname': 'YES FUTURE El Poblenou',
#   'description': "Nou model de supermercat que només ofereix productes a granel. Els clients que ho desitgin poden acudir amb els seus propis envasos reutiltzables i omplir-los sense generar residus. Si és necessari també disposen de bosses de paper, cartó o altres alternatives amb certificació ecològica.<br />\nHi ha al voltant de 300 referències de productes alimentaris i detergents a granel respectuosos amb l'ambient i biodegradables. Tenen ampolles de HDPE, que és l'únic plàstic de la botiga i exclusivament per productes de neteja. És un tipus de plàstic que no després toxines, és molt resistent i reutilitzable, a més de reciclable.<br />\nTambé hi ha utensilis de neteja fets amb materials naturals, biodegradables i compostables.",
#   'web': 'http://www.yesfuture.store/',
#   'adress': 'Carrer de Pujades, 197',
#   'district': 'Sant Martí',
#   'neighbourhood': 'El Poblenou',
#   'location': "('41,40295122', '2,20223109')",
#   'type': 'supermarket'},
#  {'shopname': 'Teixidor taula i cuina',
#   'description': "<br />\nEn aquest comerç podem trobar diferents productes que ens permetran reduir els nostres residus diaris, com per exemple carmanyoles, tapes de silicona, silicona per congelar, portaentrepans, fundes d'entrepans grans, bosses de roba per anar a comprar, el naturpod (per allargar la vida de les fruites i verdures de la nevera), brita, filtres de carbó actiu, paelles fetes amb material reciclat, o cantimplores, entre d'altres.",
#   'web': 'https://www.angelteixido.com/',
#   'adress': 'Carrer Pallars, 224',
#   'district': 'Sant Martí',
#   'neighbourhood': 'El Poblenou',
#   'location': "('41,40262570', '2,19991290')",
#   'type': 'supermarket'},
#  {'shopname': 'Cruixent',
#   'description': "En aquest forn amb obrador propi s'elaboren tot tipus de pans artesanalment a partir de massa mare elaborada amb diferents tipus de llavors i fermentacions. A més, totes les farines integrals i de llavors especials tenen certificacions ecològiques.<br />\n\xa0",
#   'web': 'https://josep028.wixsite.com/cruixent',
#   'adress': 'C/ Pujades, 173',
#   'district': 'Sant Martí',
#   'neighbourhood': 'El Poblenou',
#   'location': "('41,40188090', '2,20072905')",
#   'type': 'bakery'},
#  {'shopname': 'Forn Santanach',
#   'description': "<br />\nEn aquest forn de pa utilitzen farines de proximitat sense químics i procuren respectar el mètode tradicional per fer el pa. A la mateixa botiga tenen un obrador propi on elaboren tots els productes.<br />\nPer tal d'ajudar a la seva clientela a reduir els seus residus, cada any donen bosses de roba del pa per fomentar alternatives als materials d'un sol ús. Col·laboren amb una associació de dones en risc d'exclusió social, que els hi fan aquestes bosses.",
#   'web': '',
#   'adress': 'Rambla del Poblenou, 98',
#   'district': 'Sant Martí',
#   'neighbourhood': 'El Poblenou',
#   'location': "('41,40219475', '2,19993512')",
#   'type': 'vegan food'},
#  {'shopname': 'La cervecita nuestra de cada día',
#   'description': 'Aquesta cerveseria ven 8 tipus diferents de cervesa artesana a granel. Tenen envasos reutilitzables a la venta i també accepten envasos que portis de casa.',
#   'web': '',
#   'adress': 'Carrer de Llull, 184',
#   'district': 'Sant Martí',
#   'neighbourhood': 'El Poblenou',
#   'location': "('41,40035650', '2,20158850')",
#   'type': 'supermarket'}]

# %%
 with open('shops.csv') as f:
    print(list(csv.DictReader(f, skipinitialspace=True)))
# Out:
# [{'': '153', 'shopname': 'Vida Meva', 'description': "Aquest comerç porta ja més de 10 anys al barri fomentant el consum responsable. Seguint la filosofia de la botiga, treballen amb fruita i verdura directament de pagesos d'horta ecològica, de temporada i de proximitat escurçant els circuits de comercialització en la mesura del possible. Tenen un ampli ventall de productes a granel i alguns productes ecològics empaquetats. A més, també s'hi poden trobar ampolles d’aigua retornables de vidre.<br />\nIncentiven la utilització de materials reutilitzables però també ofereixen bosses de paper reciclat. L'oferta és aproximadament un 90% de productes ecològics i la resta són petits artesans de proximitat. Tenen una secció que es diu “El racó dels convidats” segons temporada aposten per petits productors amb propostes sostenibles, per exemple en aquesta secció hi podem trobar la marca “imperfect”.<br />\nOrganitzen sortides per conèixer els productors que els proveeixen els productes.<br />\n\xa0", 'web': 'https://vidameva.com/', 'adress': 'Carrer Ramon Turró, 201', 'district': 'Sant Martí', 'neighbourhood': 'El Poblenou', 'location': "('41,40045850', '2,20339790')", 'type': 'restaurant', 'timetable': '', 'photo': '', 'product_list': '', 'phone': ''}, {'': '323', 'shopname': 'Bodega El Mallorquí', 'description': 'Establiment on es poden trobar vi, licors i altres begudes a granel i embotellades, algunes ecològiques. Cervesa artesana', 'web': '', 'adress': 'Carrer de Verdi, 61', 'district': 'Gràcia', 'neighbourhood': 'Vila de Gràcia', 'location': "('41,40461780', '2,15601690')", 'type': 'bakery', 'timetable': '', 'photo': '', 'product_list': '', 'phone': ''}, {'': '385', 'shopname': 'The Tea World', 'description': "The Tea World neix el setembre de 2011, com a negoci familiar enfocat al món del te i el cafè.<br />\nMitjançant la nostra botiga i experiència, volem crear un punt de referència per a amants de te a granel de la millor qualitat i cafè de la seva millor producció.<br />\n\xa0<br />\nDisposem de més de 145 referències de Te, Infusions i Rooibos a granel, procedents directament de les millors zones de producció a nivell mundial. Els nostres Cafès procedeixen de les més importants zones de producció, Amèrica del Sud i Àfrica.<br />\n\xa0<br />\nA The Tea World treballem per aconseguir la millor qualitat i varietat dels nostres productes.<br />\n\xa0<br />\nA més, disposem d'una àmplia gamma d'accessoris i complements per a l'ús i gaudi del Te i el Cafè.<br />\n\xa0<br />\n<br />\nEt donem la benvinguda a la nostra botiga virtual!", 'web': 'https://www.theteaworld.es/', 'adress': 'Carrer Marina, 271', 'district': 'Eixample', 'neighbourhood': 'Sagrada Família', 'location': "('41,40508280', '2,17348830')", 'type': 'local food', 'timetable': '', 'photo': '', 'product_list': '', 'phone': ''}, {'': '418', 'shopname': 'La Botiga Natural', 'description': 'Alimentació i herbodietètica ECO. Fruita, verdura i nous a granel. El producte és de proximitat en la mesura del possible, tenen algun producte de comerç just i ofereixen bosses compostables.', 'web': 'https://labotiganatural.com/index.php?', 'adress': 'Carrer Rosselló, 441', 'district': 'Eixample', 'neighbourhood': 'Sagrada Família', 'location': "('41,40575950', '2,17366950')", 'type': 'supermarket', 'timetable': '', 'photo': '', 'product_list': '', 'phone': ''}, {'': '656', 'shopname': 'Espai Bici', 'description': 'Espai dedicat a la bicicleta com a mitjà de transport. Venda i taller de reparació de bicicletes.', 'web': 'http://www.espaibici.com', 'adress': 'Carrer Bruc, 63', 'district': 'Eixample', 'neighbourhood': "Dreta de l'Eixample", 'location': "('41,39368290', '2,17021380')", 'type': 'supermarket', 'timetable': '', 'photo': '', 'product_list': '', 'phone': ''}, {'': '657', 'shopname': 'PanAmà - La tradició del pa', 'description': 'Forn de pa artesà fet a mà, elaborat amb massa mare i fermentació lenta de 12 hores.<br />\nUtilitzen 4 tipus de farina ecològica i de proximitat  ...
